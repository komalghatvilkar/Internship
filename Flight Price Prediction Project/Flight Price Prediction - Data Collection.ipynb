# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

import warnings
warnings.filterwarnings("ignore")

from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/101.0.4951.41/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\HP\.wdm\drivers\chromedriver\win32\101.0.4951.41]

# %%
url = 'https://www.cleartrip.com/'
driver.get(url)

# %%
city=driver.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[2]/div/div[3]/div[1]/div[1]/div/div/div[1]/input")
city.send_keys('mumbai')

# %%
click=driver.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[2]/div/div[3]/div[1]/div[1]/div/div/div[2]/ul/li/p")
click.click()

# %%
city1=driver.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[2]/div/div[3]/div[1]/div[5]/div/div/div[1]/input")
city1.send_keys('London')

# %%
click=driver.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[2]/div/div[3]/div[1]/div[5]/div/div/div[2]/ul/li[1]/p")
click.click()

# %%
button=driver.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[2]/div/div[3]/div[3]/div/div/div/div/button[1]")
button.click()

# %%
date=driver.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[2]/div/div[3]/div[3]/div/div/div/div/div/ul/div[2]/div/div[2]/div[1]/div[3]/div[5]/div[6]/div/div")
date.click()

# %%
search=driver.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/div/div[2]/div/div[7]/div[2]/button")
search.click()

# %%
# Mumbai-London Flight Details

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
t = []
dest= driver.find_elements_by_xpath("//span[@class='bg-warning-100 br-100 fw-600 fs-2 lh-copy px-2 py-0']")
for i in dest:
    t.append(i.text)
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('1 May',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df=pd.DataFrame({'Airline Name':a,'Source':s,'Destination':t,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df['Date Of Journey'] = '30 Apr'
df
# Out:
#           Airline Name Source Destination                  Route  \
# 0   SriLankan Airlines    BOM         LHR        BOM → CMB → LHR
# 1              Vistara    BOM         LHR        BOM → DEL → LHR
# 2              Vistara    BOM         LHR        BOM → DEL → LHR
# 3            Air India    BOM         LHR  BOM → IDR → DEL → LHR
# 4             Emirates    BOM         LGW        BOM → DXB → LGW
# 5             Emirates    BOM         LGW        BOM → DXB → LGW
# 6              Vistara    BOM         LHR  BOM → HYD → DEL → LHR
# 7            Air India    BOM         LHR              BOM → LHR
# 8              Vistara    BOM         LHR        BOM → DEL → LHR
# 9              Vistara    BOM         LHR        BOM → DEL → LHR
# 10           Air India    BOM         LHR  BOM → GOI → DEL → LHR
# 11           Air India    BOM         LHR        BOM → ATQ → LHR
# 12     Virgin Atlantic    BOM         LHR              BOM → LHR
# ...

# %%
search=driver.find_element_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[5]/div/div[2]")
search.click()

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
t = []
dest= driver.find_elements_by_xpath("//span[@class='bg-warning-100 br-100 fw-600 fs-2 lh-copy px-2 py-0']")
for i in dest:
    t.append(i.text)
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('2 May',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df2=pd.DataFrame({'Airline Name':a,'Source':s,'Destination':t,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df2['Date Of Journey'] = '01 May'
df2
# Out:
#           Airline Name Source Destination                  Route  \
# 0   SriLankan Airlines    BOM         LHR        BOM → CMB → LHR
# 1            Air India    BOM         LHR        BOM → DEL → LHR
# 2             Emirates    BOM         LGW        BOM → DXB → LGW
# 3              Vistara    BOM         LHR        BOM → DEL → LHR
# 4            Air India    BOM         LHR        BOM → DEL → LHR
# 5              Vistara    BOM         LHR        BOM → DEL → LHR
# 6       Kuwait Airways    BOM         LHR        BOM → KWI → LHR
# 7            Air India    BOM         LHR  BOM → GOI → DEL → LHR
# 8            Air India    BOM         LHR  BOM → GOI → DEL → LHR
# 9       Oman Av (SAOG)    BOM         LHR        BOM → MCT → LHR
# 10           Air India    BOM         LHR  BOM → BLR → DEL → LHR
# 11           Air India    BOM         LHR  BOM → BLR → DEL → LHR
# 12             Vistara    BOM         LHR  BOM → HYD → DEL → LHR
# ...

# %%
search=driver.find_element_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[5]/div/div[3]")
search.click()

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
t = []
dest= driver.find_elements_by_xpath("//span[@class='bg-warning-100 br-100 fw-600 fs-2 lh-copy px-2 py-0']")
for i in dest:
    t.append(i.text)
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('3 May',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df3=pd.DataFrame({'Airline Name':a,'Source':s,'Destination':t,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df3['Date Of Journey'] = '02 May'
df3
# Out:
#           Airline Name Source Destination                  Route  \
# 0   SriLankan Airlines    BOM         LHR        BOM → CMB → LHR
# 1   SriLankan Airlines    BOM         LHR        BOM → CMB → LHR
# 2              Vistara    BOM         LHR        BOM → DEL → LHR
# 3            Air India    BOM         LHR        BOM → DEL → LHR
# 4        Ethiopian Air    BOM         LHR        BOM → ADD → LHR
# 5              Vistara    BOM         LHR        BOM → DEL → LHR
# 6              Vistara    BOM         LHR        BOM → DEL → LHR
# 7              Vistara    BOM         LHR        BOM → DEL → LHR
# 8            Air India    BOM         LHR        BOM → DEL → LHR
# 9            Air India    BOM         LHR  BOM → GOI → DEL → LHR
# 10      Oman Av (SAOG)    BOM         LHR        BOM → MCT → LHR
# 11           Air India    BOM         LHR  BOM → BLR → DEL → LHR
# 12             Vistara    BOM         LHR  BOM → HYD → DEL → LHR
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
t = []
dest= driver.find_elements_by_xpath("//span[@class='bg-warning-100 br-100 fw-600 fs-2 lh-copy px-2 py-0']")
for i in dest:
    t.append(i.text)
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('4 May',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df4=pd.DataFrame({'Airline Name':a,'Source':s,'Destination':t,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df4['Date Of Journey'] = '03 May'
df4
# Out:
#           Airline Name Source Destination                  Route  \
# 0   SriLankan Airlines    BOM         LHR        BOM → CMB → LHR
# 1            Air India    BOM         LHR              BOM → LHR
# 2              Vistara    BOM         LHR        BOM → DEL → LHR
# 3              Vistara    BOM         LHR        BOM → DEL → LHR
# 4            Air India    BOM         LHR        BOM → DEL → LHR
# 5        Ethiopian Air    BOM         LHR        BOM → ADD → LHR
# 6             Emirates    BOM         LGW        BOM → DXB → LGW
# 7              Vistara    BOM         LHR  BOM → HYD → DEL → LHR
# 8       Kuwait Airways    BOM         LHR        BOM → KWI → LHR
# 9            Air India    BOM         LHR  BOM → GOI → DEL → LHR
# 10           Air India    BOM         LHR  BOM → BLR → DEL → LHR
# 11           Egypt Air    BOM         LHR        BOM → CAI → LHR
# 12       Kenya Airways    BOM         LHR        BOM → NBO → LHR
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
t = []
dest= driver.find_elements_by_xpath("//span[@class='bg-warning-100 br-100 fw-600 fs-2 lh-copy px-2 py-0']")
for i in dest:
    t.append(i.text)
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('4 May',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df5=pd.DataFrame({'Airline Name':a,'Source':s,'Destination':t,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df5['Date Of Journey'] = '04 May'
df5
# Out:
#           Airline Name Source Destination                  Route  \
# 0   SriLankan Airlines    BOM         LHR        BOM → CMB → LHR
# 1   SriLankan Airlines    BOM         LHR        BOM → CMB → LHR
# 2             Gulf Air    BOM         LHR        BOM → BAH → LHR
# 3       Etihad Airways    BOM         LHR        BOM → AUH → LHR
# 4             Emirates    BOM         LGW        BOM → DXB → LGW
# ..                 ...    ...         ...                    ...
# 56    Multiple carrier    BOM         LCY  BOM → DEL → AMS → LCY
# 57     KLM Royal Dutch    BOM         LCY        BOM → AMS → LCY
# 58     KLM Royal Dutch    BOM         LCY  BOM → CDG → AMS → LCY
# 59    Multiple carrier    BOM         LCY  BOM → CDG → AMS → LCY
# 60    Multiple carrier    BOM         LHR        BOM → RUH → LHR
#
#    Departure Time Arrival Time Duration Total Stops      Price Date Of Journey
# 0           20:40   20:005 May  27h 50m      1 stop    ₹49,236          04 May
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
t = []
dest= driver.find_elements_by_xpath("//span[@class='bg-warning-100 br-100 fw-600 fs-2 lh-copy px-2 py-0']")
for i in dest:
    t.append(i.text)
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('4 May',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df6=pd.DataFrame({'Airline Name':a,'Source':s,'Destination':t,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df6['Date Of Journey'] = '05 May'
df6
# Out:
#         Airline Name Source Destination                  Route Departure Time  \
# 0      Qatar Airways    BOM         LHR        BOM → DOH → LHR          18:35
# 1      Qatar Airways    BOM         LHR        BOM → DOH → LHR          18:35
# 2            Vistara    BOM         LHR        BOM → DEL → LHR          10:25
# 3          Air India    BOM         LHR        BOM → DEL → LHR          10:00
# 4   Multiple carrier    BOM         MAN  BOM → AUH → BRU → MAN          20:55
# ..               ...    ...         ...                    ...            ...
# 56   KLM Royal Dutch    BOM         MAN        BOM → AMS → MAN          02:25
# 57        Air France    BOM         MAN        BOM → CDG → MAN          02:10
# 58   KLM Royal Dutch    BOM         MAN  BOM → CDG → AMS → MAN          02:10
# 59  Multiple carrier    BOM         MAN        BOM → DXB → MAN          04:30
# 60  Multiple carrier    BOM         LHR        BOM → BAH → LHR          21:45
#
# ...

# %%
Flight=pd.concat([df,df2,df3,df4,df5,df6])
Flight
# Out:
#           Airline Name Source Destination                  Route  \
# 0   SriLankan Airlines    BOM         LHR        BOM → CMB → LHR
# 1              Vistara    BOM         LHR        BOM → DEL → LHR
# 2              Vistara    BOM         LHR        BOM → DEL → LHR
# 3            Air India    BOM         LHR  BOM → IDR → DEL → LHR
# 4             Emirates    BOM         LGW        BOM → DXB → LGW
# ..                 ...    ...         ...                    ...
# 56     KLM Royal Dutch    BOM         MAN        BOM → AMS → MAN
# 57          Air France    BOM         MAN        BOM → CDG → MAN
# 58     KLM Royal Dutch    BOM         MAN  BOM → CDG → AMS → MAN
# 59    Multiple carrier    BOM         MAN        BOM → DXB → MAN
# 60    Multiple carrier    BOM         LHR        BOM → BAH → LHR
#
#    Departure Time Arrival Time Duration Total Stops      Price Date Of Journey
# 0           03:10        20:00  21h 20m      1 stop    ₹64,734          30 Apr
# ...

# %%
# Mumbai-SanFrancisco Flight Details

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
t = []
dest= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[3]/span")
for i in dest:
    t.append(i.text)
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('1 May',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df7=pd.DataFrame({'Airline Name':a,'Source':s,'Destination':t,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df7['Date Of Journey'] = '30 Apr'
df7
# Out:
#         Airline Name Source Destination                  Route Departure Time  \
# 0      Singapore Air    BOM         LAX  BOM → SIN → LAX → SJC          11:45
# 1   Multiple carrier    BOM         SEA  BOM → CDG → SEA → SJC          02:10
# 2   Multiple carrier    BOM         LAX  BOM → DXB → LAX → SFO          05:10
# 3   Multiple carrier    BOM         ORD  BOM → DEL → ORD → SJC          21:55
# 4          Lufthansa    BOM         SFO        BOM → MUC → SFO          00:50
# ..               ...    ...         ...                    ...            ...
# 56  Multiple carrier    BOM         SEA  BOM → CDG → SEA → SJC          02:10
# 57  Multiple carrier    BOM         SFO        BOM → DXB → SFO          01:05
# 58  Multiple carrier    BOM         LAX  BOM → NRT → LAX → SJC          19:40
# 59  Multiple carrier    BOM         SFO        BOM → LHR → SFO          06:30
# 60  Multiple carrier    BOM         SFO        BOM → SIN → SFO          23:50
#
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
t = []
dest= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[3]/span")
for i in dest:
    t.append(i.text)
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('2 May',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df8=pd.DataFrame({'Airline Name':a,'Source':s,'Destination':t,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df8['Date Of Journey'] = '01 May'
df8
# Out:
#         Airline Name Source Destination                  Route Departure Time  \
# 0   Multiple carrier    BOM         SLC  BOM → CDG → SLC → SJC          02:10
# 1   Multiple carrier    BOM         LHR  BOM → DXB → LHR → SFO          22:20
# 2         Air France    BOM         LHR  BOM → CDG → LHR → SFO          02:10
# 3   Multiple carrier    BOM         LAX  BOM → DOH → LAX → SJC          18:35
# 4              Delta    BOM         SFO        BOM → CDG → SFO          02:10
# ..               ...    ...         ...                    ...            ...
# 60  Multiple carrier    BOM         SEA  BOM → DOH → SEA → SJC          04:25
# 61  Multiple carrier    BOM         SEA  BOM → DXB → SEA → SJC          05:10
# 62  Multiple carrier    BOM         SFO        BOM → DXB → SFO          01:05
# 63             Delta    BOM         LAX  BOM → AMS → LAX → SJC          02:20
# 64  Multiple carrier    BOM         LAX  BOM → AMS → LAX → SJC          02:20
#
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
t = []
dest= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[3]/span")
for i in dest:
    t.append(i.text)
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('3 May',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df9=pd.DataFrame({'Airline Name':a,'Source':s,'Destination':t,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df9['Date Of Journey'] = '02 May'
df9
# Out:
#         Airline Name Source Destination                        Route  \
# 0      Singapore Air    BOM         LAX        BOM → SIN → LAX → SJC
# 1           Emirates    BOM         SFO              BOM → DXB → SFO
# 2      Qatar Airways    BOM         LAX        BOM → DOH → LAX → SJC
# 3              Delta    BOM         SEA        BOM → AMS → SEA → SJC
# 4   Multiple carrier    BOM         SEA        BOM → AMS → SEA → SJC
# 5           Emirates    BOM         SFO              BOM → DXB → SFO
# 6      Qatar Airways    BOM         LAX        BOM → DOH → LAX → SJC
# 7   Turkish Airlines    BOM         SFO              BOM → IST → SFO
# 8      Qatar Airways    BOM         SFO              BOM → DOH → SFO
# 9           Emirates    BOM         SFO              BOM → DXB → SFO
# 10  Multiple carrier    BOM         SEA        BOM → DXB → SEA → SJC
# 11  Multiple carrier    BOM         LHR        BOM → DXB → LHR → SFO
# 12             Delta    BOM         SFO              BOM → AMS → SFO
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
t = []
dest= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[3]/span")
for i in dest:
    t.append(i.text)
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('4 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df10=pd.DataFrame({'Airline Name':a,'Source':s,'Destination':t,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df10['Date Of Journey'] = '03 May'
df10
# Out:
#         Airline Name Source Destination                        Route  \
# 0      Singapore Air    BOM         LAX        BOM → SIN → LAX → SJC
# 1           Emirates    BOM         SFO              BOM → DXB → SFO
# 2      Singapore Air    BOM         NRT  BOM → SIN → NRT → LAX → SJC
# 3   Multiple carrier    BOM         SEA        BOM → DXB → SEA → SJC
# 4           Emirates    BOM         JFK        BOM → DXB → JFK → SJC
# 5          Lufthansa    BOM         SFO              BOM → FRA → SFO
# 6              Delta    BOM         SFO              BOM → CDG → SFO
# 7              Delta    BOM         SEA        BOM → CDG → SEA → SJC
# 8              Delta    BOM         LAX        BOM → CDG → LAX → SJC
# 9         Air France    BOM         SFO              BOM → CDG → SFO
# 10          Emirates    BOM         JFK        BOM → DXB → JFK → SJC
# 11          Emirates    BOM         SFO              BOM → DXB → SFO
# 12  Turkish Airlines    BOM         SFO              BOM → IST → SFO
# ...

# %%
Flight1=pd.concat([df7,df8,df9,df10])
Flight1
# Out:
#         Airline Name Source Destination                  Route Departure Time  \
# 0      Singapore Air    BOM         LAX  BOM → SIN → LAX → SJC          11:45
# 1   Multiple carrier    BOM         SEA  BOM → CDG → SEA → SJC          02:10
# 2   Multiple carrier    BOM         LAX  BOM → DXB → LAX → SFO          05:10
# 3   Multiple carrier    BOM         ORD  BOM → DEL → ORD → SJC          21:55
# 4          Lufthansa    BOM         SFO        BOM → MUC → SFO          00:50
# ..               ...    ...         ...                    ...            ...
# 45  Multiple carrier    BOM         SFO        BOM → DXB → SFO          23:05
# 46     Qatar Airways    BOM         LAX  BOM → DOH → LAX → SJC          04:25
# 47  Multiple carrier    BOM         SFO        BOM → DXB → SFO          01:05
# 48  Multiple carrier    BOM         SEA  BOM → CDG → SEA → SJC          02:10
# 49  Multiple carrier    BOM         SEA  BOM → CDG → SEA → SJC          02:10
#
# ...

# %%
# Goa-Dubai Flight Details

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('1 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df11=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df11['Date Of Journey'] = '30 Apr'
df11
# Out:
#           Airline Name Source                  Route Departure Time  \
# 0       Oman Av (SAOG)    GOI        GOI → MCT → DXB          21:00
# 1            Air India    BLR        BLR → GOI → DXB          17:00
# 2   SriLankan Airlines    BLR        BLR → CMB → DXB          03:30
# 3            Air India    GOI              GOI → DXB          20:00
# 4           Air Arabia    GOI              GOI → SHJ          04:45
# 5               IndiGo    GOI        GOI → BOM → AUH          18:40
# 6           Air Arabia    GOI              GOI → SHJ          04:45
# 7               IndiGo    GOI        GOI → BOM → DXB          18:40
# 8             SpiceJet    GOI        GOI → BOM → DXB          13:30
# 9               IndiGo    GOI        GOI → BOM → DXB          13:10
# 10             Vistara    BLR        BLR → BOM → DXB          09:30
# 11              IndiGo    GOI        GOI → BOM → DXB          06:45
# 12              IndiGo    GOI        GOI → HYD → SHJ          22:00
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('2 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df12=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df12['Date Of Journey'] = '01 May'
df12
# Out:
#         Airline Name Source                        Route Departure Time  \
# 0             IndiGo    GOI              GOI → BOM → AUH          06:45
# 1          Air India    GOI                    GOI → DXB          20:00
# 2         Air Arabia    GOI                    GOI → SHJ          04:45
# 3             IndiGo    GOI              GOI → BOM → AUH          13:10
# 4             IndiGo    GOI              GOI → BLR → DXB          02:25
# 5             IndiGo    GOI              GOI → BOM → AUH          16:30
# 6         Air Arabia    GOI                    GOI → SHJ          04:45
# 7             IndiGo    GOI              GOI → ATQ → SHJ          23:05
# 8            Vistara    GOI              GOI → BOM → DXB          08:40
# 9             IndiGo    GOI              GOI → BOM → DXB          00:10
# 10          SpiceJet    GOI              GOI → BOM → DXB          13:30
# 11            IndiGo    GOI              GOI → HYD → SHJ          07:20
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('3 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df13=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df13['Date Of Journey'] = '02 May'
df13
# Out:
#         Airline Name Source                  Route Departure Time  \
# 0             IndiGo    GOI        GOI → BOM → AUH          18:40
# 1           SpiceJet    GOI        GOI → BOM → DXB          03:45
# 2             IndiGo    GOI        GOI → BOM → DXB          18:40
# 3           SpiceJet    GOI        GOI → BOM → DXB          13:30
# 4             IndiGo    GOI        GOI → BOM → DXB          06:45
# 5             IndiGo    GOI        GOI → ATQ → SHJ          23:05
# 6             IndiGo    GOI        GOI → BLR → DXB          02:25
# 7             IndiGo    GOI        GOI → BOM → DXB          13:10
# 8             IndiGo    GOI        GOI → HYD → SHJ          07:20
# 9             IndiGo    GOI        GOI → DEL → DXB          00:50
# 10          SpiceJet    GOI        GOI → DEL → DXB          18:10
# 11            IndiGo    GOI        GOI → HYD → SHJ          15:15
# 12            IndiGo    GOI        GOI → LKO → DXB          18:30
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('4 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df14=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df14['Date Of Journey'] = '03 May'
df14
# Out:
#         Airline Name Source            Route Departure Time Arrival Time  \
# 0             IndiGo    GOI  GOI → BOM → AUH          06:45        23:25
# 1           GO FIRST    GOI  GOI → BOM → AUH          06:40        22:10
# 2         Air Arabia    GOI        GOI → SHJ          04:45        06:30
# 3         Air Arabia    GOI        GOI → SHJ          04:45        06:30
# 4             IndiGo    GOI  GOI → BOM → DXB          00:10        10:25
# ..               ...    ...              ...            ...          ...
# 57     Qatar Airways    BLR  BLR → DOH → SHJ          03:55        09:50
# 58  Multiple carrier    BLR  BLR → HYD → AUH          20:10   07:004 May
# 59  Multiple carrier    GOI  GOI → LHR → AUH          04:35   00:354 May
# 60  Multiple carrier    BLR  BLR → LHR → AUH          06:50   00:354 May
# 61         Lufthansa    BLR  BLR → FRA → AUH          03:05        19:20
#
#    Duration Total Stops      Price Date Of Journey
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('5 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df15=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df15['Date Of Journey'] = '04 May'
df15
# Out:
#         Airline Name Source                        Route Departure Time  \
# 0             IndiGo    GOI              GOI → BOM → AUH          06:45
# 1             IndiGo    GOI              GOI → BOM → AUH          00:10
# 2             IndiGo    GOI              GOI → BOM → AUH          18:40
# 3             IndiGo    GOI              GOI → BOM → DXB          06:45
# 4             IndiGo    GOI              GOI → BOM → AUH          13:10
# 5             IndiGo    GOI              GOI → BOM → DXB          00:10
# 6             IndiGo    GOI              GOI → ATQ → SHJ          23:05
# 7             IndiGo    GOI              GOI → DEL → AUH          15:25
# 8             IndiGo    GOI              GOI → HYD → SHJ          07:20
# 9           SpiceJet    GOI              GOI → BOM → DXB          13:30
# 10            IndiGo    GOI              GOI → BOM → DXB          18:40
# 11            IndiGo    GOI              GOI → DEL → AUH          13:00
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('6 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df16=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df16['Date Of Journey'] = '05 May'
df16
# Out:
#         Airline Name Source                  Route Departure Time  \
# 0             IndiGo    GOI        GOI → BOM → AUH          06:45
# 1             IndiGo    GOI        GOI → BOM → AUH          18:40
# 2             IndiGo    GOI        GOI → BOM → DXB          06:45
# 3             IndiGo    GOI        GOI → ATQ → SHJ          23:05
# 4             IndiGo    GOI        GOI → BOM → DXB          18:40
# 5             IndiGo    GOI        GOI → HYD → SHJ          07:20
# 6             IndiGo    GOI        GOI → BOM → AUH          16:30
# 7             IndiGo    GOI        GOI → HYD → DXB          02:05
# 8             IndiGo    GOI        GOI → BLR → DXB          02:25
# 9             IndiGo    GOI        GOI → HYD → SHJ          22:00
# 10            IndiGo    GOI        GOI → BOM → DXB          00:10
# 11          SpiceJet    GOI        GOI → BOM → DXB          13:30
# 12            IndiGo    GOI        GOI → DEL → AUH          15:25
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('7 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df17=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df17['Date Of Journey'] = '06 May'
df17
# Out:
#         Airline Name Source                  Route Departure Time  \
# 0             IndiGo    GOI        GOI → BOM → AUH          06:45
# 1           GO FIRST    GOI        GOI → BOM → AUH          06:40
# 2             IndiGo    GOI        GOI → BLR → DXB          02:25
# 3           GO FIRST    GOI        GOI → BOM → AUH          13:15
# 4             IndiGo    GOI        GOI → BOM → AUH          16:30
# 5             IndiGo    GOI        GOI → HYD → SHJ          15:15
# 6             IndiGo    GOI        GOI → BOM → DXB          06:45
# 7             IndiGo    GOI        GOI → BOM → AUH          18:40
# 8             IndiGo    GOI        GOI → BOM → DXB          00:10
# 9             IndiGo    GOI        GOI → BOM → AUH          13:10
# 10          SpiceJet    GOI        GOI → BOM → DXB          13:30
# 11            IndiGo    GOI        GOI → ATQ → SHJ          23:05
# 12            IndiGo    GOI        GOI → HYD → DXB          02:05
# ...

# %%
Flight2=pd.concat([df11,df12,df13,df14,df15,df16,df17])
Flight2['Destination'] = 'DXB'
Flight2
# Out:
#           Airline Name Source                  Route Departure Time  \
# 0       Oman Av (SAOG)    GOI        GOI → MCT → DXB          21:00
# 1            Air India    BLR        BLR → GOI → DXB          17:00
# 2   SriLankan Airlines    BLR        BLR → CMB → DXB          03:30
# 3            Air India    GOI              GOI → DXB          20:00
# 4           Air Arabia    GOI              GOI → SHJ          04:45
# ..                 ...    ...                    ...            ...
# 54    Multiple carrier    GOI        GOI → BLR → DXB          22:50
# 55    Multiple carrier    GOI        GOI → DEL → DXB          18:10
# 56    Multiple carrier    GOI  GOI → DEL → DOH → SHJ          21:55
# 57    Multiple carrier    GOI        GOI → LHR → AUH          04:35
# 58    Multiple carrier    GOI        GOI → LHR → DXB          04:35
#
#    Arrival Time Duration Total Stops      Price Date Of Journey Destination
# ...

# %%
# Mumbai-Singapore Flight Details

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('1 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df18=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df18['Date Of Journey'] = '30 Apr'
df18
# Out:
#           Airline Name Source                  Route Departure Time  \
# 0   SriLankan Airlines    BOM        BOM → CMB → SIN          03:10
# 1               IndiGo    BOM        BOM → CCU → SIN          17:35
# 2               IndiGo    BOM        BOM → CCU → SIN          12:55
# 3               IndiGo    BOM        BOM → BLR → SIN          14:40
# 4               IndiGo    BOM        BOM → BLR → SIN          11:45
# 5         Thai Airways    BOM        BOM → BKK → SIN          23:35
# 6   SriLankan Airlines    BOM        BOM → CMB → SIN          20:40
# 7               IndiGo    BOM        BOM → MAA → SIN          16:45
# 8            Air India    BOM  BOM → GOI → DEL → SIN          05:05
# 9            Air India    BOM  BOM → GOI → DEL → SIN          21:00
# 10           Air India    BOM        BOM → DEL → SIN          19:00
# 11    Multiple carrier    BOM  BOM → MAA → CMB → SIN          09:45
# 12       Singapore Air    BOM              BOM → SIN          11:45
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('2 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df19=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df19['Date Of Journey'] = '01 May'
df19
# Out:
#          Airline Name Source                  Route Departure Time  \
# 0              IndiGo    BOM        BOM → BLR → SIN          14:40
# 1           Air India    BOM        BOM → DEL → SIN          19:00
# 2              IndiGo    BOM        BOM → MAA → SIN          22:15
# 3              IndiGo    BOM        BOM → CCU → SIN          17:35
# 4              IndiGo    BOM        BOM → MAA → SIN          00:20
# 5           Air India    BOM              BOM → SIN          23:50
# 6              IndiGo    BOM        BOM → MAA → SIN          16:45
# 7           Air India    BOM        BOM → MAA → SIN          05:25
# 8             Vistara    BOM              BOM → SIN          02:30
# 9           Air India    BOM  BOM → BLR → DEL → SIN          06:50
# 10          Air India    BOM  BOM → BLR → DEL → SIN          09:30
# 11          Air India    BOM  BOM → GOI → DEL → SIN          05:05
# 12          Air India    BOM  BOM → BLR → DEL → SIN          06:50
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('3 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df20=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df20['Date Of Journey'] = '02 May'
df20
# Out:
#           Airline Name Source                  Route Departure Time  \
# 0               IndiGo    BOM        BOM → MAA → SIN          00:20
# 1               IndiGo    BOM        BOM → BLR → SIN          14:40
# 2               IndiGo    BOM        BOM → BLR → SIN          11:45
# 3               IndiGo    BOM        BOM → MAA → SIN          22:15
# 4               IndiGo    BOM        BOM → MAA → SIN          19:40
# 5              Vistara    BOM              BOM → SIN          02:30
# 6               IndiGo    BOM        BOM → BLR → SIN          09:55
# 7            Air India    BOM              BOM → SIN          23:50
# 8               IndiGo    BOM        BOM → MAA → SIN          16:45
# 9            Air India    BOM        BOM → DEL → SIN          19:00
# 10       Singapore Air    BOM              BOM → SIN          23:40
# 11        Thai Airways    BOM        BOM → BKK → SIN          23:35
# 12           Air India    BOM        BOM → MAA → SIN          05:25
# ...

# %%
Flight3=pd.concat([df18,df19,df20])
Flight3['Destination'] = 'SIN'
Flight3
# Out:
#           Airline Name Source            Route Departure Time Arrival Time  \
# 0   SriLankan Airlines    BOM  BOM → CMB → SIN          03:10        18:55
# 1               IndiGo    BOM  BOM → CCU → SIN          17:35   04:301 May
# 2               IndiGo    BOM  BOM → CCU → SIN          12:55   04:301 May
# 3               IndiGo    BOM  BOM → BLR → SIN          14:40   03:201 May
# 4               IndiGo    BOM  BOM → BLR → SIN          11:45   03:201 May
# ..                 ...    ...              ...            ...          ...
# 32    Multiple carrier    BOM  BOM → LHR → SIN          10:15   16:553 May
# 33    Multiple carrier    BOM  BOM → LHR → SIN          10:15   17:453 May
# 34    Multiple carrier    BOM  BOM → ZRH → SIN          05:15   05:553 May
# 35           Lufthansa    BOM  BOM → MUC → SIN          00:50   07:003 May
# 36    Multiple carrier    BOM  BOM → MUC → SIN          00:50   07:003 May
#
#    Duration Total Stops      Price Date Of Journey Destination
# ...

# %%
# Mumbai-Dubai Flight Details

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('2 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df21=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df21['Date Of Journey'] = '01 May'
df21
# Out:
#          Airline Name Source            Route Departure Time Arrival Time  \
# 0              IndiGo    BOM        BOM → AUH          22:00        23:25
# 1          Air Arabia    BOM        BOM → SHJ          21:50        23:15
# 2   Air India Express    BOM        BOM → SHJ          02:20        04:00
# 3          Air Arabia    BOM        BOM → SHJ          04:55        06:20
# 4            SpiceJet    BOM        BOM → DXB          23:05   00:402 May
# ..                ...    ...              ...            ...          ...
# 88    British Airways    BOM  BOM → LHR → DXB          13:10   07:302 May
# 89   Multiple carrier    BOM  BOM → LHR → AUH          12:15   06:152 May
# 90   Multiple carrier    BOM  BOM → LHR → AUH          13:10   06:152 May
# 91   Multiple carrier    BOM  BOM → FRA → AUH          02:50        19:20
# 92          Lufthansa    BOM  BOM → FRA → DXB          02:50        22:35
#
#    Duration Total Stops      Price Date Of Journey
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)  
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('3 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df22=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df22['Date Of Journey'] = '02 May'
df22
# Out:
#          Airline Name Source            Route Departure Time Arrival Time  \
# 0              IndiGo    BOM        BOM → AUH          22:00        23:25
# 1          Air Arabia    BOM        BOM → SHJ          04:55        06:20
# 2   Air India Express    BOM        BOM → SHJ          06:20        08:00
# 3            SpiceJet    BOM        BOM → DXB          23:05   00:403 May
# 4          Air Arabia    BOM        BOM → SHJ          04:55        06:20
# ..                ...    ...              ...            ...          ...
# 83    British Airways    BOM  BOM → LHR → DXB          13:10   07:303 May
# 84   Multiple carrier    BOM  BOM → DEL → AUH          17:35        23:20
# 85   Multiple carrier    BOM  BOM → LHR → AUH          12:15   06:153 May
# 86   Multiple carrier    BOM  BOM → LHR → AUH          13:10   06:153 May
# 87     Swiss Intl Air    BOM  BOM → ZRH → DXB          05:15        21:30
#
#    Duration Total Stops      Price Date Of Journey
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('4 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df23=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df23['Date Of Journey'] = '03 May'
df23
# Out:
#           Airline Name Source            Route Departure Time Arrival Time  \
# 0               IndiGo    BOM        BOM → AUH          22:00        23:25
# 1           Air Arabia    BOM        BOM → SHJ          04:55        06:20
# 2               IndiGo    BOM        BOM → DXB          02:25        04:00
# 3    Air India Express    BOM        BOM → SHJ          02:20        04:00
# 4           Air Arabia    BOM        BOM → SHJ          21:50        23:15
# ..                 ...    ...              ...            ...          ...
# 97     British Airways    BOM  BOM → LHR → DXB          13:10   07:304 May
# 98    Multiple carrier    BOM  BOM → LHR → AUH          12:15   06:154 May
# 99    Multiple carrier    BOM  BOM → LHR → AUH          13:10   06:154 May
# 100          Lufthansa    BOM  BOM → FRA → DXB          02:50        22:35
# 101          Lufthansa    BOM  BOM → FRA → AUH          02:50        19:20
#
#     Duration Total Stops      Price Date Of Journey
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)   
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('5 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df24=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df24['Date Of Journey'] = '04 May'
df24
# Out:
#           Airline Name Source            Route Departure Time Arrival Time  \
# 0               IndiGo    BOM        BOM → AUH          22:00        23:25
# 1               IndiGo    BOM        BOM → DXB          02:25        04:00
# 2    Air India Express    BOM        BOM → SHJ          02:20        04:00
# 3           Air Arabia    BOM        BOM → SHJ          04:55        06:20
# 4           Air Arabia    BOM        BOM → SHJ          04:55        06:20
# ..                 ...    ...              ...            ...          ...
# 97    Multiple carrier    BOM  BOM → LHR → AUH          12:15   06:155 May
# 98    Multiple carrier    BOM  BOM → LHR → AUH          13:10   06:155 May
# 99           Lufthansa    BOM  BOM → FRA → DXB          02:50        22:35
# 100     Swiss Intl Air    BOM  BOM → ZRH → DXB          05:15        21:30
# 101          Lufthansa    BOM  BOM → FRA → AUH          02:50        19:20
#
#     Duration Total Stops      Price Date Of Journey
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('6 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df25=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df25['Date Of Journey'] = '05 May'
df25
# Out:
#         Airline Name Source            Route Departure Time Arrival Time  \
# 0             IndiGo    BOM        BOM → AUH          22:00        23:25
# 1             IndiGo    BOM        BOM → DXB          19:35        21:00
# 2           SpiceJet    BOM        BOM → DXB          23:05   00:406 May
# 3         Air Arabia    BOM        BOM → SHJ          04:55        06:20
# 4             IndiGo    BOM        BOM → DXB          08:55        10:25
# ..               ...    ...              ...            ...          ...
# 85  Multiple carrier    BOM  BOM → DEL → AUH          17:35        23:20
# 86  Multiple carrier    BOM  BOM → LHR → AUH          12:15   06:156 May
# 87        All Nippon    BOM  BOM → NRT → AUH          19:40   23:456 May
# 88   British Airways    BOM  BOM → LHR → DXB          13:10   07:306 May
# 89  Multiple carrier    BOM  BOM → LHR → AUH          13:10   06:156 May
#
#    Duration Total Stops      Price Date Of Journey
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)  
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('7 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df26=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df26['Date Of Journey'] = '06 May'
df26
# Out:
#         Airline Name Source                  Route Departure Time  \
# 0             IndiGo    BOM              BOM → AUH          22:00
# 1         Air Arabia    BOM              BOM → SHJ          21:50
# 2         Air Arabia    BOM              BOM → SHJ          21:50
# 3             IndiGo    BOM              BOM → DXB          02:25
# 4           GO FIRST    BOM              BOM → AUH          20:40
# ..               ...    ...                    ...            ...
# 93  Multiple carrier    BOM        BOM → CAI → AUH          03:15
# 94  Multiple carrier    BOM  BOM → DEL → DOH → SHJ          06:30
# 95  Multiple carrier    BOM        BOM → DEL → AUH          17:35
# 96   British Airways    BOM        BOM → LHR → DXB          13:10
# 97    Swiss Intl Air    BOM        BOM → ZRH → DXB          05:15
#
#    Arrival Time Duration Total Stops      Price Date Of Journey
# 0         23:25   2h 55m    non-stop    ₹14,062          06 May
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text)
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df27=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df27['Date Of Journey'] = '07 May'
df27
# Out:
#          Airline Name Source                  Route Departure Time  \
# 0              IndiGo    BOM              BOM → DXB          02:25
# 1   Air India Express    BOM              BOM → SHJ          02:20
# 2           Air India    BOM        BOM → CCJ → DXB          06:40
# 3           Air India    BOM              BOM → DXB          01:05
# 4            GO FIRST    BOM              BOM → AUH          20:40
# ..                ...    ...                    ...            ...
# 95   Multiple carrier    BOM  BOM → DEL → DOH → SHJ          06:30
# 96    British Airways    BOM        BOM → LHR → DXB          13:10
# 97   Multiple carrier    BOM        BOM → DEL → AUH          17:35
# 98   Multiple carrier    BOM        BOM → LHR → AUH          13:10
# 99         All Nippon    BOM        BOM → NRT → AUH          19:40
#
#    Arrival Time Duration Total Stops      Price Date Of Journey
# 0         04:00    3h 5m    non-stop    ₹17,701          07 May
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)   
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('9 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df28=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df28['Date Of Journey'] = '08 May'
df28
# Out:
#           Airline Name Source                  Route Departure Time  \
# 0             GO FIRST    BOM              BOM → AUH          20:40
# 1    Air India Express    BOM              BOM → SHJ          02:20
# 2               IndiGo    BOM        BOM → HYD → SHJ          19:55
# 3            Air India    BOM        BOM → DEL → DXB          19:00
# 4               IndiGo    BOM              BOM → DXB          02:25
# ..                 ...    ...                    ...            ...
# 102   Multiple carrier    BOM  BOM → BLR → DOH → SHJ          21:30
# 103   Multiple carrier    BOM        BOM → MAA → AUH          21:00
# 104   Multiple carrier    BOM  BOM → DEL → DOH → SHJ          06:30
# 105   Multiple carrier    BOM        BOM → BLR → DXB          07:00
# 106          Lufthansa    BOM        BOM → FRA → AUH          02:50
#
#     Arrival Time Duration Total Stops      Price Date Of Journey
# 0          22:10    3h 0m    non-stop    ₹20,518          08 May
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('10 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df29=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df29['Date Of Journey'] = '09 May'
df29
# Out:
#          Airline Name Source            Route Departure Time Arrival Time  \
# 0              IndiGo    BOM        BOM → AUH          22:00        23:25
# 1          Air Arabia    BOM        BOM → SHJ          21:50        23:15
# 2            flydubai    BOM        BOM → DWC          05:10        06:55
# 3            SpiceJet    BOM        BOM → DWC          23:55  01:3010 May
# 4          Air Arabia    BOM        BOM → SHJ          21:50        23:15
# ..                ...    ...              ...            ...          ...
# 96   Multiple carrier    BOM  BOM → DEL → AUH          17:35        23:20
# 97          Lufthansa    BOM  BOM → FRA → DXB          02:50        22:35
# 98     Swiss Intl Air    BOM  BOM → ZRH → DXB          05:15        20:45
# 99          Lufthansa    BOM  BOM → MUC → AUH          00:50        19:55
# 100         Lufthansa    BOM  BOM → FRA → AUH          02:50        19:20
#
#     Duration Total Stops      Price Date Of Journey
# ...

# %%
a = []
air= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[1]/div/p")
for i in air:
    a.append(i.text)
s = []
sourc= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p/div[1]/span")
for i in sourc:
    s.append(i.text)    
r = []
rout= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[4]/p")
for i in rout:
    r.append(i.text)
dt = []
dtime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[1]/p")
for i in dtime:
    dt.append(i.text)
at = []
atime= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[2]/p")
for i in atime:
    at.append(i.text.replace('11 may',''))
u = []
dura= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[3]/p")
for i in dura:
    u.append(i.text)
ts = []
stop= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[2]/div/div[5]/p")
for i in stop:
    ts.append(i.text)
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div/main/div/div/div[2]/div[2]/div[8]/div/div[1]/div[2]/div[3]/div[2]/div/p")
for i in price:
    p.append(i.text)

time.sleep(2)        
# creating dataframe
df30=pd.DataFrame({'Airline Name':a,'Source':s,'Route':r,'Departure Time':dt,'Arrival Time':at,'Duration':u,'Total Stops':ts,'Price':p})

# %%
df30['Date Of Journey'] = '10 May'
df30
# Out:
#           Airline Name Source            Route Departure Time Arrival Time  \
# 0             SpiceJet    BOM        BOM → DWC          23:55  01:3011 May
# 1    Air India Express    BOM        BOM → SHJ          02:20        04:00
# 2               IndiGo    BOM        BOM → AUH          22:00        23:25
# 3           Air Arabia    BOM        BOM → SHJ          21:50        23:15
# 4            Air India    BOM  BOM → COK → DXB          05:30        13:35
# ..                 ...    ...              ...            ...          ...
# 97    Multiple carrier    BOM  BOM → DEL → AUH          17:35        23:20
# 98     British Airways    BOM  BOM → LHR → DXB          08:55  07:3011 May
# 99          All Nippon    BOM  BOM → NRT → AUH          19:40  23:4511 May
# 100          Lufthansa    BOM  BOM → FRA → DXB          02:50        22:35
# 101          Lufthansa    BOM  BOM → FRA → AUH          02:50        19:20
#
#     Duration Total Stops      Price Date Of Journey
# ...

# %%
Flight4=pd.concat([df21,df22,df23,df24,df25,df26,df27,df28,df29,df30])
Flight4['Destination'] = 'DXB'
Flight4
# Out:
#           Airline Name Source            Route Departure Time Arrival Time  \
# 0               IndiGo    BOM        BOM → AUH          22:00        23:25
# 1           Air Arabia    BOM        BOM → SHJ          21:50        23:15
# 2    Air India Express    BOM        BOM → SHJ          02:20        04:00
# 3           Air Arabia    BOM        BOM → SHJ          04:55        06:20
# 4             SpiceJet    BOM        BOM → DXB          23:05   00:402 May
# ..                 ...    ...              ...            ...          ...
# 97    Multiple carrier    BOM  BOM → DEL → AUH          17:35        23:20
# 98     British Airways    BOM  BOM → LHR → DXB          08:55  07:3011 May
# 99          All Nippon    BOM  BOM → NRT → AUH          19:40  23:4511 May
# 100          Lufthansa    BOM  BOM → FRA → DXB          02:50        22:35
# 101          Lufthansa    BOM  BOM → FRA → AUH          02:50        19:20
#
#     Duration Total Stops      Price Date Of Journey Destination
# ...

# %%
FlightPrice=pd.concat([Flight,Flight1,Flight2,Flight3,Flight4])
FlightPrice
# Out:
#            Airline Name Source Destination                  Route  \
# 0    SriLankan Airlines    BOM         LHR        BOM → CMB → LHR
# 1               Vistara    BOM         LHR        BOM → DEL → LHR
# 2               Vistara    BOM         LHR        BOM → DEL → LHR
# 3             Air India    BOM         LHR  BOM → IDR → DEL → LHR
# 4              Emirates    BOM         LGW        BOM → DXB → LGW
# ..                  ...    ...         ...                    ...
# 97     Multiple carrier    BOM         DXB        BOM → DEL → AUH
# 98      British Airways    BOM         DXB        BOM → LHR → DXB
# 99           All Nippon    BOM         DXB        BOM → NRT → AUH
# 100           Lufthansa    BOM         DXB        BOM → FRA → DXB
# 101           Lufthansa    BOM         DXB        BOM → FRA → AUH
#
#     Departure Time Arrival Time Duration Total Stops      Price  \
# 0            03:10        20:00  21h 20m      1 stop    ₹64,734
# ...

# %%
FlightPrice.to_excel("FlightPricePredictionData.xlsx",sheet_name='FlightPricePrediction')

# %% [markdown]
# # Thank You...!!!
