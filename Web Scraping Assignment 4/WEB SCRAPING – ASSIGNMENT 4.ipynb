# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

import warnings
warnings.filterwarnings("ignore")

from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/98.0.4758.102/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\HP\.wdm\drivers\chromedriver\win32\98.0.4758.102]

# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
url = 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)

# %%
# A) Rank B) Name C) Artist D) Upload date E) Views

# %%
rank = driver.find_elements_by_xpath('/html/body/div[3]/div[3]/div[5]/div[1]/table[3]/tbody/tr/td[1]')
r = []
for i in rank:
    r.append(i.text)
name = driver.find_elements_by_xpath('/html/body/div[3]/div[3]/div[5]/div[1]/table[3]/tbody/tr/td[2]')
n = []
for i in name:
    n.append(i.text)
artist = driver.find_elements_by_xpath('/html/body/div[3]/div[3]/div[5]/div[1]/table[3]/tbody/tr/td[3]')
a = []
for i in artist:
    a.append(i.text)
date = driver.find_elements_by_xpath('/html/body/div[3]/div[3]/div[5]/div[1]/table[3]/tbody/tr/td[5]')
d = []
for i in date:
    d.append(i.text)
views = driver.find_elements_by_xpath('/html/body/div[3]/div[3]/div[5]/div[1]/table[3]/tbody/tr/td[4]')
v = []
for i in views:
    v.append(i.text)

# Dataframe of all the tabs
YouTube=pd.DataFrame()
YouTube['Rank']=r
YouTube['Name']=n
YouTube['Artist']=a
YouTube['Upload Date']=d
YouTube['Views']=v
YouTube
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.  "Learning Colors – Colorful Eggs on a Farm"[21]
# 7    8.   "Masha and the Bear – Recipe for Disaster"[22]
# 8    9.                "Phonics Song with Two Words"[23]
# 9   10.                                "Uptown Funk"[24]
# 10  11.                              "Gangnam Style"[25]
# 11  12.                             "Dame Tu Cosita"[30]
# 12  13.                          "Wheels on the Bus"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# ...

# %% [markdown]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1
# st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
url = 'https://www.bcci.tv/'
driver.get(url)

# %%
international=driver.find_element_by_xpath("/html/body/nav/div/div[2]/ul[1]/li[2]/a")
international.click()

# %%
fixtures=driver.find_element_by_xpath("/html/body/div[3]/div[2]/div/div/div/div[2]/div[3]/div[2]/div/button")
fixtures.click()

# %%
fixtures=driver.find_element_by_xpath("/html/body/div[3]/div[2]/div/div/div/div[2]/div[3]/div[2]/div/button")
fixtures.click()

# %%
# A) Match title (I.e. 1 st ODI) B) Series C) Place D) Date E) Time Note

# %%
title = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div/div/div/div[2]/div[3]/div/div/div/div[1]/h5[2]/span')
t = []
for i in title:
    t.append(i.text)
series = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div/div/div/div[2]/div[3]/div/div/div/div[3]')
s = []
for i in series:
    s.append(i.text.replace('\n',' '))
place = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div/div/div/div[2]/div[3]/div/div/div/div[4]/div')
p = []
for i in place:
    p.append(i.text)
date = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div/div/div/div[2]/div[3]/div/div/div/div[1]/div/div[1]/h5')
d = []
for i in date:
    d.append(i.text)
time = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div/div/div/div[2]/div[3]/div/div/div/div[1]/div/div[2]/h5')
e = []
for i in time:
    e.append(i.text)

# Dataframe of all the tabs
Match=pd.DataFrame()
Match['Match Title']=t
Match['Series']=s
Match['Place']=p
Match['Date']=d
Match['Time']=e
Match
# Out:
#                                         Match Title  \
# 0   INDIA WOMEN TOUR OF NEW ZEALAND ODI SERIES 2022
# 1   INDIA WOMEN TOUR OF NEW ZEALAND ODI SERIES 2022
# 2           SRI LANKA TOUR OF INDIA T20 SERIES 2022
# 3           SRI LANKA TOUR OF INDIA T20 SERIES 2022
# 4           SRI LANKA TOUR OF INDIA T20 SERIES 2022
# 5          SRI LANKA TOUR OF INDIA TEST SERIES 2022
# 6                         ICC WOMENS WORLD CUP 2022
# 7                         ICC WOMENS WORLD CUP 2022
# 8          SRI LANKA TOUR OF INDIA TEST SERIES 2022
# 9                         ICC WOMENS WORLD CUP 2022
# 10                        ICC WOMENS WORLD CUP 2022
# 11                        ICC WOMENS WORLD CUP 2022
# 12                        ICC WOMENS WORLD CUP 2022
# 13                        ICC WOMENS WORLD CUP 2022
# 14       SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 15       SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 16       SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# ...

# %% [markdown]
# 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
url = 'https://www.guru99.com/'
driver.get(url)

# %%
international=driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[2]/div[1]/div/ul[1]/li[3]/a")
international.click()

# %%
exception=driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a")
exception.click()

# %%
# A) Name B) Description

# %%
name = driver.find_elements_by_xpath('/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr/td[1]')
n = []
for i in name:
    n.append(i.text)
desc = driver.find_elements_by_xpath('/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr/td[2]')
d = []
for i in desc:
    d.append(i.text)

# Dataframe of all the tabs
Selenium=pd.DataFrame()
Selenium['Name']=n
Selenium['Description']=d
Selenium
# Out:
#                                    Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [markdown]
# 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP
# D) GSDP
# E) Share
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
url = 'http://statisticstimes.com/'
driver.get(url)

# %%
economy=driver.find_element_by_xpath("/html/body/div[2]/div[1]/div[2]/div[2]/button")
economy.click()

# %%
india=driver.find_element_by_xpath("/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]")
india.click()

# %%
gdp=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")
gdp.click()

# %%
# A) Rank B) State C) GSDP D) GSDP E) Share F) GDP($ billion)

# %%
rank = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[1]')
r = []
for i in rank:
    r.append(i.text)
state = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[2]')
s = []
for i in state:
    s.append(i.text)
gsdp = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[3]')
c = []
for i in gsdp:
    c.append(i.text)
gsdp1 = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[4]')
c1 = []
for i in gsdp1:
    c1.append(i.text)
gsdp11 = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[7]')
c11 = []
for i in gsdp11:
    c11.append(i.text)
gsdp12 = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[8]')
c12 = []
for i in gsdp12:
    c12.append(i.text)
share = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[5]')
sh = []
for i in share:
    sh.append(i.text)
gdp = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[6]')
g = []
for i in gdp:
    g.append(i.text)

# Dataframe of all the tabs
GDP=pd.DataFrame({"Rank":r,"State":s,"GSDP(Cr INR at Current prices):19-20":c,"GSDP(Cr INR at Current prices):18-19":c1,"GSDP(Cr INR at 2011-12 prices):19-20":c11,"GSDP(Cr INR at 2011-12 prices):18-19":c12,"Share":sh,"GDP($billion)":g})
GDP
# Out:
#    Rank                      State GSDP(Cr INR at Current prices):19-20  \
# 0     1                Maharashtra                                    -
# 1     2                 Tamil Nadu                            1,845,853
# 2     3              Uttar Pradesh                            1,687,818
# 3     4                    Gujarat                                    -
# 4     5                  Karnataka                            1,631,977
# 5     6                West Bengal                            1,253,832
# 6     7                  Rajasthan                            1,020,989
# 7     8             Andhra Pradesh                              972,782
# 8     9                  Telangana                              969,604
# 9    10             Madhya Pradesh                              906,672
# 10   11                     Kerala                                    -
# 11   12                      Delhi                              856,112
# ...

# %% [markdown]
# 5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
# ASSIGNMENT
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
url = 'https://github.com/'
driver.get(url)

# %%
explore=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary")
explore.click()

# %%
trend=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")
trend.click()

# %%
# A) Repository title B) Repository description C) Contributors count D) Language used ASSIGNMENT

# %%
title = driver.find_elements_by_xpath('/html/body/div[4]/main/div[3]/div/div[2]/article/h1/a')
t = []
for i in title:
    t.append(i.text)
desc = driver.find_elements_by_xpath('/html/body/div[4]/main/div[3]/div/div[2]/article/p')
d = []
for i in desc:
    d.append(i.text)
count = driver.find_elements_by_xpath('/html/body/div[4]/main/div[3]/div/div[2]/article/div[2]/a[2]')
c = []
for i in count:
    c.append(i.text)
language = driver.find_elements_by_xpath('/html/body/div[4]/main/div[3]/div/div[2]/article/div[2]/span[1]')
l = []
for i in language:
    l.append(i.text)

# Dataframe of all the tabs
GitHUb=pd.DataFrame({"Repository Title":t,"Repository Description":d,"Contributors Count":c,"Language Used Assignment":l})
GitHUb
# Out:
#                       Repository Title  \
# 0               Anduin2017 / HowToCook
# 1          lwthiker / curl-impersonate
# 2   donnemartin / system-design-primer
# 3      cryptotwinsbr / spacecrypto-bot
# 4          freeCodeCamp / freeCodeCamp
# 5                   saadeghi / daisyui
# 6                         emilk / egui
# 7     iranremote / awesome-iran-remote
# 8                  libevent / libevent
# 9          littlefs-project / littlefs
# 10  swisskyrepo / PayloadsAllTheThings
# 11              BishopFox / unredacter
# 12                 supabase / supabase
# 13               harmonoid / harmonoid
# 14                        openai / gym
# 15              withfig / autocomplete
# 16          openvinotoolkit / anomalib
# 17                    odin-lang / Odin
# 18                 google / googletest
# 19               beurtschipper / Depix
# 20                   metowolf / vCards
# 21                     neovim / neovim
# 22                NVlabs / instant-ngp
# ...

# %% [markdown]
# 6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
url = 'https:/www.billboard.com/'
driver.get(url)

# %%
charts=driver.find_element_by_xpath("/html/body/div[4]/header/div[1]/div/div/div[2]/div/nav/ul/li[1]/a")
charts.click()

# %%
hot100=driver.find_element_by_xpath("/html/body/div[4]/header/div[2]/div/nav/ul/li[1]/a")
hot100.click()

# %%
# A) Song name B) Artist name C) Last week rank D) Peak rank E) Weeks on board Note

# %%
name = driver.find_elements_by_xpath('/html/body/div[4]/main/div[2]/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[1]/h3')
n = []
for i in name:
    n.append(i.text)
artist = driver.find_elements_by_xpath('/html/body/div[4]/main/div[2]/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[1]/span')
a = []
for i in artist:
    a.append(i.text)
lastrank = driver.find_elements_by_xpath('/html/body/div[4]/main/div[2]/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[7]/ul/li[3]/span')
lr = []
for i in lastrank:
    lr.append(i.text)
rank = driver.find_elements_by_xpath('/html/body/div[4]/main/div[2]/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[7]/ul/li[4]/span')
r = []
for i in rank:
    r.append(i.text)
weeks = driver.find_elements_by_xpath('/html/body/div[4]/main/div[2]/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[7]/ul/li[5]/span')
w = []
for i in weeks:
    w.append(i.text)
    
# Dataframe of all the tabs
billboard=pd.DataFrame({"Song Name":n,"Artist Name":a,"Last Week Rank":lr,"Peak Rank":r,"Weeks On Board Note":w})
billboard
# Out:
#                     Song Name  \
# 0   We Don't Talk About Bruno
# 1       Do We Have A Problem?
# 2                  Easy On Me
# 3                  Heat Waves
# 4                        Stay
# ..                        ...
# 95                       Iffy
# 96              When I'm Gone
# 97                 Fair Trade
# 98              Megan's Piano
# 99            Moth To A Flame
#
#                                           Artist Name Last Week Rank  \
# 0   Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...              1
# 1                              Nicki Minaj X Lil Baby              -
# 2                                               Adele              2
# 3                                       Glass Animals              3
# 4                       The Kid LAROI & Justin Bieber              4
# ..                                                ...            ...
# 95                                        Chris Brown             87
# ...

# %% [markdown]
# 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
url = 'https://www.naukri.com/naukri-dot-com-recruiters'
driver.get(url)

# %%
key=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[2]/div/form/div[1]/div/div[1]/div[1]/div[2]/input")
key.send_keys('Data science')

# %%
recruiters=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[2]/div/form/div[1]/button")
recruiters.click()

# %%
# A) Name B) Designation C) Company D) Skills they hire for E) Location

# %%
#make empty listes
name = [] 
designation = [] 
company = [] 
age = []
skills = [] 
location = []

while(True):
    Name= driver.find_elements_by_xpath("//span[@class='fl ellipsis']")
    for i in Name:
        name.append(i.text)
    time.sleep(1)
    Designation = driver.find_elements_by_xpath("//span[@class='ellipsis clr']")
    for i in Designation:
        designation.append(i.text)
    time.sleep(1)
    Company= driver.find_elements_by_xpath("//a[@class='ellipsis']")
    for i in Company:
        company.append(i.text)   
    time.sleep(1)
    Skills= driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")
    for i in Skills:
        skills.append(i.text)
    time.sleep(1)
    Location = driver.find_elements_by_xpath("//span[@class='ellipsis']")
    for i in Location:
        location.append(i.text)    
    time.sleep(1)
        
    try:
        next_button = driver.find_element_by_xpath("//button[@class='grayBtn']")
        next_button.click()
    except:
        break  

        
jobs = []        
for i in range(0,len(location),2):
        jobs.append(location[i])
    

time.sleep(2)        
#creating dataframe
df=pd.DataFrame({'Name':name,
                'Designation':designation,
                'Company':company,
                'Skills they hire for':skills,
                'Location':location})
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c742062039bc> in <module>
#      19     for i in Company:
#      20         company.append(i.text)
# ---> 21     time.sleep(1)
#      22     Skills= driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")
#      23     for i in Skills:
#
# KeyboardInterrupt:

# %% [markdown]
# 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
url = 'https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
driver.get(url)

# %%
# A) Book name B) Author name C) Volumes sold D) Publisher E) Genre

# %%
name = driver.find_elements_by_xpath('/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr/td[2]')
n = []
for i in name:
    n.append(i.text)
author = driver.find_elements_by_xpath('/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr/td[3]')
a = []
for i in author:
    a.append(i.text)
sold = driver.find_elements_by_xpath('/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr/td[4]')
s = []
for i in sold:
    s.append(i.text)
publisher = driver.find_elements_by_xpath('/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr/td[5]')
p = []
for i in publisher:
    p.append(i.text)
genre = driver.find_elements_by_xpath('/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr/td[6]')
g = []
for i in genre:
    g.append(i.text)

# Dataframe of all the tabs
books=pd.DataFrame({"Book Name":n,"Author Name":a,"Volumes Sold":s,"Publisher":p,"Genre":g})
books
# Out:
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes Sold        Publisher                        Genre
# ...

# %% [markdown]
# 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
url = 'https://www.imdb.com/list/ls095964455/'
driver.get(url)

# %%
# A) Name B) Year span C) Genre D) Run time E) Ratings F) Votes

# %%
name = driver.find_elements_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/h3/a')
n = []
for i in name:
    n.append(i.text)
year = driver.find_elements_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/h3/span[2]')
y = []
for i in year:
    y.append(i.text)
genre = driver.find_elements_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/p[1]/span[5]')
g = []
for i in genre:
    g.append(i.text)
time = driver.find_elements_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/p[1]/span[3]')
t = []
for i in time:
    t.append(i.text)
rate = driver.find_elements_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/div[1]/div[1]/span[2]')
r = []
for i in rate:
    r.append(i.text)
vote = driver.find_elements_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/p[4]/span[2]')
v = []
for i in vote:
    v.append(i.text)

# Dataframe of all the tabs
tvshows=pd.DataFrame({"Name":n,"Year Span":y,"Genre":g,"Run Time":t,"Ratings":r,"Votes":v})
tvshows
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  1,954,611
# ...

# %% [markdown]
# 10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
url = ' https://archive.ics.uci.edu/'
driver.get(url)

# %%
All=driver.find_element_by_xpath("/html/body/table[1]/tbody/tr/td[2]/span[2]/a")
All.click()

# %%
# A) Dataset name B) Data type C) Task D) Attribute type E) No of instances F) No of attribute G) Year

# %%
name = driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a')
n = []
for i in name:
    n.append(i.text)
Type = driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]/p')
t = []
for i in Type:
    t.append(i.text)
task = driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]/p')
k = []
for i in task:
    k.append(i.text)
attr = driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]/p')
a = []
for i in attr:
    a.append(i.text)
inst = driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]/p')
s = []
for i in inst:
    s.append(i.text)
att = driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]/p')
o = []
for i in att:
    o.append(i.text)
year = driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]/p')
y = []
for i in year:
    y.append(i.text)

# Dataframe of all the tabs
data=pd.DataFrame({"Dataset Name":n,"Data Type":t[1:623],"Task":k[1:623],"Attribute Type":a[1:623],"No Of Instances":s[1:623],"No Of Attribute":o[1:623],"Year":y[1:623]})
data
# Out:
#                                           Dataset Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data Type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...
