# %%
# Import Libraries
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import requests
from webdriver_manager.chrome import ChromeDriverManager

# %%
# Connect To Web Driver
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/101.0.4951.41/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\HP\.wdm\drivers\chromedriver\win32\101.0.4951.41]

# %%
# Scrape the reviews of different laptops, Phones, Headphones, smart watches, Professional Cameras, Printers, Monitors, Home theater, Router

# %%
# Get The Webpage
url = 'https://www.flipkart.com/hp-pavilion-ryzen-5-hexa-core-5600h-8-gb-512-gb-ssd-windows-10-4-graphics-nvidia-geforce-gtx-1650-144-hz-15-ec2004ax-gaming-laptop/p/itm98c94bbf9bc20?pid=COMG5GZXPWMGTNWS&lid=LSTCOMG5GZXPWMGTNWSQE9WVW&marketplace=FLIPKART&store=6bo%2Fb5g&srno=b_1_6&otracker=browse&fm=organic&iid=0b354208-2471-4b1b-99de-cf2bda0b0f82.COMG5GZXPWMGTNWS.SEARCH&ppt=browse&ppn=browse&ssid=54u8aye39c0000001653805786283'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[6]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,65,1):
    
    page_url = "https://www.flipkart.com/hp-pavilion-ryzen-5-hexa-core-5600h-8-gb-512-gb-ssd-windows-10-4-graphics-nvidia-geforce-gtx-1650-144-hz-15-ec2004ax-gaming-laptop/product-reviews/itm98c94bbf9bc20?pid=COMG5GZXPWMGTNWS&lid=LSTCOMG5GZXPWMGTNWSQE9WVW&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=640
r = [i[0] for i in element_list[ : R]]

RS=640
rs = [i[1] for i in element_list[ : RS]]

FR=640
fr = [i[2] for i in element_list[ : FR]]

lap=pd.DataFrame()
lap['Rating']=r
lap['Review_Summary']=rs
lap['Full_Review']=fr

# %%
Product_Name = 'HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/512 GB SSD/Windows 10/4 GB Graphics/NVIDIA GeForce GTX 1650/144 Hz) 15-ec2004AX Gaming'

# %%
lap['Product_Name'] = Product_Name
lap
# Out:
#     Rating         Review_Summary  \
# 0        5  Mind-blowing purchase
# 1        4              Wonderful
# 2        5         Simply awesome
# 3        5    Best in the market!
# 4        5  Mind-blowing purchase
# ..     ...                    ...
# 635      5      Worth every penny
# 636      5    Best in the market!
# 637      5                Awesome
# 638      5       Perfect product!
# 639      5              Brilliant
#
#                                            Full_Review  \
# 0    Pros :-\nRyzen 5 (5600h) beast 😍\nDisplay is a...
# 1    I have used this laptop for one week and my ob...
# 2    If you're looking for a best budget gaming lap...
# 3    No compromise in performance and the thermals ...
# 4    1)Trust me guys this is awesome Laptop 💻 in bu...
# ..                                                 ...
# 635  Been using this bad boy for about 3 months. He...
# 636  **Review after 2 days of usage\n\nIt's a reall...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/infinix-inbook-x1-core-i3-10th-gen-8-gb-256-gb-ssd-windows-11-home-xl11-thin-light-laptop/p/itm31001568d44e2?pid=COMG8Z3HYFECKTU7&lid=LSTCOMG8Z3HYFECKTU78DBGXC&marketplace=FLIPKART&store=6bo%2Fb5g&srno=b_1_7&otracker=browse&fm=organic&iid=0b354208-2471-4b1b-99de-cf2bda0b0f82.COMG8Z3HYFECKTU7.SEARCH&ppt=browse&ppn=browse&ssid=54u8aye39c0000001653805786283'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[6]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,61,1):
    
    page_url = "https://www.flipkart.com/infinix-inbook-x1-core-i3-10th-gen-8-gb-256-gb-ssd-windows-11-home-xl11-thin-light-laptop/product-reviews/itm31001568d44e2?pid=COMG8Z3HYFECKTU7&lid=LSTCOMG8Z3HYFECKTU78DBGXC&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=610
r = [i[0] for i in element_list[ : R]]

RS=610
rs = [i[1] for i in element_list[ : RS]]

FR=610
fr = [i[2] for i in element_list[ : FR]]

lap1=pd.DataFrame()
lap1['Rating']=r
lap1['Review_Summary']=rs
lap1['Full_Review']=fr

# %%
Product_Name = 'Infinix INBook X1 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 11 Home) XL11 Thin and Light Laptop'

# %%
lap1['Product_Name'] = Product_Name
lap1
# Out:
#     Rating       Review_Summary  \
# 0        5  Best in the market!
# 1        5     Perfect product!
# 2        5  Best in the market!
# 3        5       Classy product
# 4        5            Excellent
# ..     ...                  ...
# 595      3                 Good
# 596      4            Very Good
# 597      5               Super!
# 598      5            Excellent
# 599      5            Brilliant
#
#                                            Full_Review  \
# 0    No other laptops can't beat this, at this pric...
# 1    First of all the design is superb. Its compact...
# 2    1.First Flipkart Love it ❤️ Very Fast Delivery...
# 3    Just Brilliant ♥️, no match at 33k highly reco...
# 4    The build quality display battery and speakers...
# ..                                                 ...
# 595  They not provide the support we have face some...
# 596  The design and build quality seems premium. Th...
# 597  Ohh my god what a laptop it's brilliant.\nMy w...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/acer-aspire-7-core-i5-10th-gen-8-gb-512-gb-ssd-windows-10-home-4-graphics-nvidia-geforce-gtx-1650-a715-75g-50ta-a715-75g-41g-a715-75g-52aa-gaming-laptop/p/itm365d5a348ad9c?pid=COMG2KBG2K4GFFF7&lid=LSTCOMG2KBG2K4GFFF75TIZXH&marketplace=FLIPKART&store=6bo%2Fb5g&spotlightTagId=BestvalueId_6bo%2Fb5g&srno=b_2_34&otracker=browse&fm=neo%2Fmerchandising&iid=fa261dfa-59c7-4a25-9040-b03a1fa0f233.COMG2KBG2K4GFFF7.SEARCH&ppt=browse&ppn=browse&ssid=znd4d1xsxs0000001653810428010'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[8]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,130,1):
    
    page_url = "https://www.flipkart.com/acer-aspire-7-core-i5-10th-gen-8-gb-512-gb-ssd-windows-10-home-4-graphics-nvidia-geforce-gtx-1650-a715-75g-50ta-a715-75g-41g-a715-75g-52aa-gaming-laptop/product-reviews/itm365d5a348ad9c?pid=COMG2KBG2K4GFFF7&lid=LSTCOMG2KBG2K4GFFF75TIZXH&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=1290
r = [i[0] for i in element_list[ : R]]

RS=1290
rs = [i[1] for i in element_list[ : RS]]

FR=1290
fr = [i[2] for i in element_list[ : FR]]

lap2=pd.DataFrame()
lap2['Rating']=r
lap2['Review_Summary']=rs
lap2['Full_Review']=fr

# %%
Product_Name = 'acer Aspire 7 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GTX 1650) A715-75G-50TA/ A715-75G-41G/ A715-75G-52AA Gaming Laptop'

# %%
lap2['Product_Name'] = Product_Name
lap2
# Out:
#      Rating   Review_Summary  \
# 0         5           Superb
# 1         5        Just wow!
# 2         4        Very Good
# 3         5        Wonderful
# 4         5    Great product
# ...     ...              ...
# 1285      5    Great product
# 1286      4  Worth the money
# 1287      4     Nice product
# 1288      3             Good
# 1289      5           Super!
#
#                                             Full_Review  \
# 0     Here is my review on this laptop after using f...
# 1     Good Product, I am satisfied all of the featur...
# 2     Posting this review after 8 days of use\nPros:...
# 3     Performance is good as I expect in this price ...
# 4     Amazing laptop. It has a premium and professio...
# ...                                                 ...
# 1285  Bought it for 49990 in Big Billion Days.\nThis...
# 1286  OK it's really value for money......for this p...
# 1287  Everything is fine with the laptop. It's fast ...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/boat-rockerz-450-upto-15-hours-playback-bluetooth-headset/p/itm077a566bd128b?pid=ACCFEHZ8GSGWMMSD&lid=LSTACCFEHZ8GSGWMMSD3VEWSN&marketplace=FLIPKART&store=0pm&srno=b_1_10&otracker=hp_rich_navigation_1_2.navigationCard.RICH_NAVIGATION_Electronics~Audio~All_9JGNW7M0TUHD&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_1_L2_view-all&fm=neo%2Fmerchandising&iid=c65ca580-d92a-4933-82f2-b13372de175f.ACCFEHZ8GSGWMMSD.SEARCH&ppt=browse&ppn=browse&ssid=652ayj4gc00000001653811146639'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[7]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,600,1):
    
    page_url = "https://www.flipkart.com/boat-rockerz-450-upto-15-hours-playback-bluetooth-headset/product-reviews/itm077a566bd128b?pid=ACCFEHZ8GSGWMMSD&lid=LSTACCFEHZ8GSGWMMSD3VEWSN&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=5000
r = [i[0] for i in element_list[ : R]]

RS=5000
rs = [i[1] for i in element_list[ : RS]]

FR=5000
fr = [i[2] for i in element_list[ : FR]]

headphone=pd.DataFrame()
headphone['Rating']=r
headphone['Review_Summary']=rs
headphone['Full_Review']=fr

# %%
Product_Name = 'boAt Rockerz 450 with Upto 15 Hours Playback Bluetooth Headset'

# %%
headphone['Product_Name'] = Product_Name
headphone
# Out:
#      Rating        Review_Summary  \
# 0         5        Simply awesome
# 1         5      Perfect product!
# 2         5             Must buy!
# 3         5              Terrific
# 4         5   Best in the market!
# ...     ...                   ...
# 4995      4           Pretty good
# 4996      5    Highly recommended
# 4997      5             Fabulous!
# 4998      5   Best in the market!
# 4999      4  Good quality product
#
#                                             Full_Review  \
# 0     Review after 1week of use\n\n1. Voice is crisp...
# 1       I love it 😍 buy fast it's good bass 😁 amazing 👌
# 2     Best product at this price this design is very...
# 3     Hi, 450 ❤️\nAll about it is good\nBut, while y...
# 4     Nice 👏 headphone 🎧 very good 👍 quality small t...
# ...                                                 ...
# 4995  I am using it since 8 months... So the things ...
# 4996  Very nice product good sound quality good bass...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/oneplus-bullets-wireless-z2-fast-charge-30-hrs-battery-life-earphones-mic-bluetooth-headset/p/itm1b9cd98911a2a?pid=ACCGC4GN5SQR7ZCZ&lid=LSTACCGC4GN5SQR7ZCZJIQWGQ&marketplace=FLIPKART&store=0pm&srno=b_1_4&otracker=hp_rich_navigation_1_2.navigationCard.RICH_NAVIGATION_Electronics~Audio~All_9JGNW7M0TUHD&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_1_L2_view-all&fm=neo%2Fmerchandising&iid=c65ca580-d92a-4933-82f2-b13372de175f.ACCGC4GN5SQR7ZCZ.SEARCH&ppt=browse&ppn=browse&ssid=652ayj4gc00000001653811146639'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[5]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,267,1):
    
    page_url = "https://www.flipkart.com/oneplus-bullets-wireless-z2-fast-charge-30-hrs-battery-life-earphones-mic-bluetooth-headset/product-reviews/itm1b9cd98911a2a?pid=ACCGC4GN5SQR7ZCZ&lid=LSTACCGC4GN5SQR7ZCZJIQWGQ&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=2600
r = [i[0] for i in element_list[ : R]]

RS=2600
rs = [i[1] for i in element_list[ : RS]]

FR=2600
fr = [i[2] for i in element_list[ : FR]]

headphone1=pd.DataFrame()
headphone1['Rating']=r
headphone1['Review_Summary']=rs
headphone1['Full_Review']=fr

# %%
Product_Name = 'OnePlus Bullets Wireless Z2 with Fast Charge, 30 Hrs Battery Life, Earphones with mic Bluetooth Headset'

# %%
headphone1['Product_Name'] = Product_Name
headphone1
# Out:
#      Rating         Review_Summary  \
# 0         5         Simply awesome
# 1         5                 Super!
# 2         5         Classy product
# 3         5         Simply awesome
# 4         5  Mind-blowing purchase
# ...     ...                    ...
# 2595      4           Nice product
# 2596      4   Good quality product
# 2597      5              Brilliant
# 2598      3           Does the job
# 2599      5  Mind-blowing purchase
#
#                                             Full_Review  \
# 0     Excellent product. Superb bass. Worth for mone...
# 1     I heard song in z2 is very great if you are a ...
# 2     Wireless Bullets are first impressions are imp...
# 3     Superb product actually I won’t prefer wireles...
# 4     This is worth every penny you spend. I doesn't...
# ...                                                 ...
# 2595  👉Sound quality is excellent, Bass is awesome, ...
# 2596  Actually nothing changed too much in sound ......
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/jbl-c150si-one-button-universal-remote-wired-headset/p/itm5f6934af69fb7?pid=ACCEHDJBEJSQYYKU&lid=LSTACCEHDJBEJSQYYKUSVGO6J&marketplace=FLIPKART&store=0pm&srno=b_1_22&otracker=hp_rich_navigation_1_2.navigationCard.RICH_NAVIGATION_Electronics~Audio~All_9JGNW7M0TUHD&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_1_L2_view-all&fm=neo%2Fmerchandising&iid=c65ca580-d92a-4933-82f2-b13372de175f.ACCEHDJBEJSQYYKU.SEARCH&ppt=browse&ppn=browse&ssid=652ayj4gc00000001653811146639'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[7]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,600,1):
    
    page_url = "https://www.flipkart.com/jbl-c150si-one-button-universal-remote-wired-headset/product-reviews/itm5f6934af69fb7?pid=ACCEHDJBEJSQYYKU&lid=LSTACCEHDJBEJSQYYKUSVGO6J&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=5000
r = [i[0] for i in element_list[ : R]]

RS=5000
rs = [i[1] for i in element_list[ : RS]]

FR=5000
fr = [i[2] for i in element_list[ : FR]]

headphone2=pd.DataFrame()
headphone2['Rating']=r
headphone2['Review_Summary']=rs
headphone2['Full_Review']=fr

# %%
Product_Name = 'JBL C150SI with One Button Universal Remote Wired Headset'

# %%
headphone2['Product_Name'] = Product_Name
headphone2
# Out:
#      Rating         Review_Summary  \
# 0         4              Wonderful
# 1         5          Great product
# 2         5              Just wow!
# 3         5         Classy product
# 4         5  Mind-blowing purchase
# ...     ...                    ...
# 4995      5              Wonderful
# 4996      5    Best in the market!
# 4997      5      Worth every penny
# 4998      5              Just wow!
# 4999      5                Awesome
#
#                                             Full_Review  \
# 0     Bought it for 799 from flipkart.\nPros :\n1 sm...
# 1     Best Sound Quality. BASS is balanced. Slightly...
# 2     My review after 4 months\nSound Quality,\nBuil...
# 3     Frnds I got this product before 1 YEAR ..... s...
# 4     This product is awesome..........i've personal...
# ...                                                 ...
# 4995  Awesome quality of the bass 🎧... I mean totall...
# 4996  Best earphones in this price range...\ni bough...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/apple-iphone-11-purple-128-gb/p/itmb7ca0b05522ff?pid=MOBFWQ6BEHFXGXGB&lid=LSTMOBFWQ6BEHFXGXGBMVHGLV&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_2_28&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&fm=search-autosuggest&iid=03c32b10-766d-4283-9191-79ff01ef0916.MOBFWQ6BEHFXGXGB.SEARCH&ppt=sp&ppn=sp&ssid=2z64qc24q80000001653812832727&qH=eb4af0bf07c16429'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[6]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,638,1):
    
    page_url = "https://www.flipkart.com/apple-iphone-11-purple-128-gb/product-reviews/itmb7ca0b05522ff?pid=MOBFWQ6BEHFXGXGB&lid=LSTMOBFWQ6BEHFXGXGBMVHGLV&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=5000
r = [i[0] for i in element_list[ : R]]

RS=5000
rs = [i[1] for i in element_list[ : RS]]

FR=5000
fr = [i[2] for i in element_list[ : FR]]

mobile=pd.DataFrame()
mobile['Rating']=r
mobile['Review_Summary']=rs
mobile['Full_Review']=fr

# %%
Product_Name = 'APPLE iPhone 11 (Purple, 128 GB)'

# %%
mobile['Product_Name'] = Product_Name
mobile
# Out:
#      Rating       Review_Summary  \
# 0         5       Simply awesome
# 1         5  Best in the market!
# 2         5     Perfect product!
# 3         5            Fabulous!
# 4         5    Worth every penny
# ...     ...                  ...
# 4995      5        Great product
# 4996      5   Highly recommended
# 4997      5    Worth every penny
# 4998      4          Good choice
# 4999      5   Highly recommended
#
#                                             Full_Review  \
# 0     Really satisfied with the Product I received.....
# 1     Great iPhone very snappy experience as apple k...
# 2     Amazing phone with great cameras and better ba...
# 3     This is my first iOS phone. I am very happy wi...
# 4     Previously I was using one plus 3t it was a gr...
# ...                                                 ...
# 4995  Amazing Powerful and Durable Gadget.\n\nI’m am...
# 4996  What a camera .....just awesome ..you can feel...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/oneplus-7t-glacier-blue-256-gb/p/itma74f3aece46b1?pid=MOBFKWSYTHTESNSG&lid=LSTMOBFKWSYTHTESNSGWXY9KD&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_22&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&fm=search-autosuggest&iid=08a82657-0b3a-4010-9b04-4f50737660cb.MOBFKWSYTHTESNSG.SEARCH&ppt=sp&ppn=sp&ssid=2z64qc24q80000001653812832727&qH=eb4af0bf07c16429'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div/div/div[4]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,85,1):
    
    page_url = "https://www.flipkart.com/oneplus-7t-glacier-blue-256-gb/product-reviews/itma74f3aece46b1?pid=MOBFKWSYTHTESNSG&lid=LSTMOBFKWSYTHTESNSGWXY9KD&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=800
r = [i[0] for i in element_list[ : R]]

RS=800
rs = [i[1] for i in element_list[ : RS]]

FR=800
fr = [i[2] for i in element_list[ : FR]]

mobile1=pd.DataFrame()
mobile1['Rating']=r
mobile1['Review_Summary']=rs
mobile1['Full_Review']=fr

# %%
Product_Name = 'OnePlus 7T (Glacier Blue, 256 GB)'

# %%
mobile1['Product_Name'] = Product_Name
mobile1
# Out:
#     Rating     Review_Summary  \
# 0        5      Great product
# 1        5          Fabulous!
# 2        4        Good choice
# 3        5          Brilliant
# 4        5  Worth every penny
# ..     ...                ...
# 795      5            Awesome
# 796      5             Super!
# 797      5          Must buy!
# 798      5             Super!
# 799      5          Fabulous!
#
#                                            Full_Review  \
# 0    OnePlus 7t have Out standing Battery Performan...
# 1    After using for 3 months. I can say it is best...
# 2    Got it as a gift..was a little apprehensive af...
# 3    My first one plus device. Reviewing it after 2...
# 4    This is actually the best deal to buy. I was g...
# ..                                                 ...
# 795  Well packaged. Product is pretty good especial...
# 796  Amazing macro mode camera, super smooth interf...
# 797  That's a night view by this camera, photo qual...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/xiaomi-11i-5g-pacific-pearl-128-gb/p/itm64ae12c24445b?pid=MOBG9QXPWYHJ99GV&lid=LSTMOBG9QXPWYHJ99GVVS1JVX&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_10&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&fm=search-autosuggest&iid=0ac5f46d-d486-424a-8ab1-e1dc1fb03b81.MOBG9QXPWYHJ99GV.SEARCH&ppt=sp&ppn=sp&ssid=2z64qc24q80000001653812832727&qH=eb4af0bf07c16429'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[6]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,259,1):
    
    page_url = "https://www.flipkart.com/xiaomi-11i-5g-pacific-pearl-128-gb/product-reviews/itm64ae12c24445b?pid=MOBG9QXPWYHJ99GV&lid=LSTMOBG9QXPWYHJ99GVVS1JVX&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=2600
r = [i[0] for i in element_list[ : R]]

RS=2600
rs = [i[1] for i in element_list[ : RS]]

FR=2600
fr = [i[2] for i in element_list[ : FR]]

mobile2=pd.DataFrame()
mobile2['Rating']=r
mobile2['Review_Summary']=rs
mobile2['Full_Review']=fr

# %%
Product_Name = 'Xiaomi 11i 5G (Pacific Pearl, 128 GB)'

# %%
mobile2['Product_Name'] = Product_Name
mobile2
# Out:
#      Rating       Review_Summary  \
# 0         5            Brilliant
# 1         4           Delightful
# 2         5              Awesome
# 3         5  Best in the market!
# 4         5              Awesome
# ...     ...                  ...
# 2575      4          Pretty good
# 2576      4      Worth the money
# 2577      5  Best in the market!
# 2578      5       Simply awesome
# 2579      5            Just wow!
#
#                                             Full_Review  \
# 0     This phone looks great in real life than in im...
# 1     Pros\n1 display\n2 loud speaker👌👌\n3 good sunl...
# 2     Best phone for this budget,,,\n1st a good batt...
# 3     Phone size is quite large like we can't say th...
# 4     First of all.. Im a recent Poco x3 pro user.. ...
# ...                                                 ...
# 2575  This phone is a perfect all rounder with some ...
# 2576  Good Display, good battery, good performance a...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/boat-storm-1-3-curveddisplay-smartwatch/p/itm215a48c547168?pid=SMWG3EC4KCEFNNKH&lid=LSTSMWG3EC4KCEFNNKHJXJOIN&marketplace=FLIPKART&q=smart+watches&store=ajy%2Fbuh&srno=s_1_11&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&fm=search-autosuggest&iid=c3f5bea2-f501-4844-954a-0dd796b383ee.SMWG3EC4KCEFNNKH.SEARCH&ppt=sp&ppn=sp&ssid=iq0y0lp42o0000001653814643614&qH=87968ec020b2016b'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[8]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,700,1):
    
    page_url = "https://www.flipkart.com/boat-storm-1-3-curveddisplay-smartwatch/product-reviews/itm215a48c547168?pid=SMWG3EC4KCEFNNKH&lid=LSTSMWG3EC4KCEFNNKHJXJOIN&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=5000
r = [i[0] for i in element_list[ : R]]

RS=5000
rs = [i[1] for i in element_list[ : RS]]

FR=5000
fr = [i[2] for i in element_list[ : FR]]

smartwatch=pd.DataFrame()
smartwatch['Rating']=r
smartwatch['Review_Summary']=rs
smartwatch['Full_Review']=fr

# %%
Product_Name = 'boAt Storm 1.3" Curved Display Smartwatch'

# %%
smartwatch['Product_Name'] = Product_Name
smartwatch
# Out:
#      Rating         Review_Summary  \
# 0         4            Good choice
# 1         5          Great product
# 2         5      Worth every penny
# 3         4             Delightful
# 4         5              Excellent
# ...     ...                    ...
# 4995      5              Fabulous!
# 4996      5       Perfect product!
# 4997      5  Mind-blowing purchase
# 4998      4           Nice product
# 4999      3           Does the job
#
#                                             Full_Review  \
# 0     Writing this review after 2 weeks.\nPROS:-less...
# 1     Got the watch from Flipkart and I must say it'...
# 2     Wooww🖤Grt watch\nawesome 💌💌\n🖤I loved it super...
# 3     Boat smart watch nice and decent product in th...
# 4     Beautiful smart watch loved its look just awes...
# ...                                                 ...
# 4995  Writing this review after 11 days.\n\n1. Price...
# 4996  Good watch...👍\nUse after 10 day .and one time...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/apple-watch-series-3-gps-mtf02hn-a-38-mm-space-grey-aluminium-case-black-sport-band/p/itmc50d68ba8ca0c?pid=SMWF94AYYE5HXTGY&lid=LSTSMWF94AYYE5HXTGYF8W2C3&marketplace=FLIPKART&q=smart+watches&store=ajy%2Fbuh&srno=s_1_2&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&fm=search-autosuggest&iid=2f601e7d-96a2-46fd-9c2b-cd326d19881b.SMWF94AYYE5HXTGY.SEARCH&ppt=sp&ppn=sp&ssid=iq0y0lp42o0000001653814643614&qH=87968ec020b2016b'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[7]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,464,1):
    
    page_url = "https://www.flipkart.com/apple-watch-series-3-gps-mtf02hn-a-38-mm-space-grey-aluminium-case-black-sport-band/product-reviews/itmc50d68ba8ca0c?pid=SMWF94AYYE5HXTGY&lid=LSTSMWF94AYYE5HXTGYF8W2C3&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=4600
r = [i[0] for i in element_list[ : R]]

RS=4600
rs = [i[1] for i in element_list[ : RS]]

FR=4600
fr = [i[2] for i in element_list[ : FR]]

smartwatch1=pd.DataFrame()
smartwatch1['Rating']=r
smartwatch1['Review_Summary']=rs
smartwatch1['Full_Review']=fr

# %%
Product_Name = 'APPLE Watch Series 3 GPS - MTF02HN/A 38 mm Space Grey Aluminium Case with Black Sport Band'

# %%
smartwatch1['Product_Name'] = Product_Name
smartwatch1
# Out:
#      Rating       Review_Summary  \
# 0         5     Perfect product!
# 1         5       Classy product
# 2         5              Awesome
# 3         5       Simply awesome
# 4         5  Best in the market!
# ...     ...                  ...
# 4595      5       Classy product
# 4596      5             Terrific
# 4597      4          Pretty good
# 4598      5  Best in the market!
# 4599      5    Terrific purchase
#
#                                             Full_Review  \
# 0     Thank you for delivery it just in one day . I ...
# 1     Superb Quality , Nothing like apple , No need ...
# 2     Amazing watch ! Was lill skeptic before buying...
# 3     Just just amazing and fall in love at firs gla...
# 4     Apple watch does not need introduction..\nI am...
# ...                                                 ...
# 4595  Apple does seem to release stable product over...
# 4596  My First Apple Watch!!! Simply Amazing.\nI use...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/samsung-galaxy-watch-active-2-aluminium-smartwatch/p/itmdf82694656d9d?pid=SMWFH4MV778VZXJP&lid=LSTSMWFH4MV778VZXJPODTWFP&marketplace=FLIPKART&q=smart+watches&store=ajy%2Fbuh&srno=s_1_20&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&fm=search-autosuggest&iid=f6b9db23-76dd-4104-a979-a64baa2b0134.SMWFH4MV778VZXJP.SEARCH&ppt=sp&ppn=sp&ssid=iq0y0lp42o0000001653814643614&qH=87968ec020b2016b'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div/div/div[6]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,223,1):
    
    page_url = "https://www.flipkart.com/samsung-galaxy-watch-active-2-aluminium-smartwatch/product-reviews/itmdf82694656d9d?pid=SMWFH4MV778VZXJP&lid=LSTSMWFH4MV778VZXJPODTWFP&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=2200
r = [i[0] for i in element_list[ : R]]

RS=2200
rs = [i[1] for i in element_list[ : RS]]

FR=2200
fr = [i[2] for i in element_list[ : FR]]

smartwatch2=pd.DataFrame()
smartwatch2['Rating']=r
smartwatch2['Review_Summary']=rs
smartwatch2['Full_Review']=fr

# %%
Product_Name = 'SAMSUNG Galaxy Watch Active 2 Aluminium Smartwatch'

# %%
smartwatch2['Product_Name'] = Product_Name
smartwatch2
# Out:
#      Rating     Review_Summary  \
# 0         5          Must buy!
# 1         5          Excellent
# 2         5          Brilliant
# 3         5          Brilliant
# 4         5     Simply awesome
# ...     ...                ...
# 2195      5     Simply awesome
# 2196      5   Perfect product!
# 2197      4        Really Nice
# 2198      5          Fabulous!
# 2199      5  Terrific purchase
#
#                                             Full_Review  \
# 0     One of the Best Purchases ever made!\nI person...
# 1     Writing review after using it for 3 days.Aweso...
# 2     Awesome watch , Loved it very much. The watch ...
# 3     Awesome Watch...Must buy if you are looking ou...
# 4     Writing review after using it for 3 days :\nAw...
# ...                                                 ...
# 2195  The screen quality is good.\nBattery last for ...
# 2196  Oh wow I'm so in love with this watch 😍 look n...
# 2197  Just another great product from samsung. It's ...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/canon-eos-3000d-dslr-camera-1-body-18-55-mm-lens/p/itm6f665fea97bc2?pid=CAMF3DHJURPEMNRN&lid=LSTCAMF3DHJURPEMNRN5POEJU&marketplace=FLIPKART&q=professional+camera&store=jek%2Fp31&spotlightTagId=BestsellerId_jek%2Fp31&srno=s_1_1&otracker=search&fm=search-autosuggest&iid=511a0959-d18d-4dcf-aa28-6c34874afd05.CAMF3DHJURPEMNRN.SEARCH&ppt=browse&ppn=browse&ssid=ih2m6bdgnk0000001653816341889&qH=43a1f7122e7538f4'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div[7]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,371,1):
    
    page_url = "https://www.flipkart.com/canon-eos-3000d-dslr-camera-1-body-18-55-mm-lens/product-reviews/itm6f665fea97bc2?pid=CAMF3DHJURPEMNRN&lid=LSTCAMF3DHJURPEMNRN5POEJU&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=5000
r = [i[0] for i in element_list[ : R]]

RS=5000
rs = [i[1] for i in element_list[ : RS]]

FR=5000
fr = [i[2] for i in element_list[ : FR]]

camera=pd.DataFrame()
camera['Rating']=r
camera['Review_Summary']=rs
camera['Full_Review']=fr

# %%
Product_Name = 'Canon EOS 3000D DSLR Camera 1 Camera Body, 18 - 55 mm Lens'

# %%
camera['Product_Name'] = Product_Name
camera
# Out:
#      Rating        Review_Summary  \
# 0         5         Great product
# 1         5             Excellent
# 2         4       Worth the money
# 3         5             Just wow!
# 4         4           Really Nice
# ...     ...                   ...
# 3695      3          Does the job
# 3696      4           Really Nice
# 3697      4  Good quality product
# 3698      5   Best in the market!
# 3699      5                Super!
#
#                                             Full_Review  \
# 0     Well Reviewing this after using for almost one...
# 1     product really great . I am totally sctified t...
# 2     The camera simply awesome..and it is a best bu...
# 3     Worth more than the amount. Best DSLR for a go...
# 4     Excellent for someone who is new into photogra...
# ...                                                 ...
# 3695  Satisfied with the product.. Its a really good...
# 3696  The product is very good\nBut if I take anothe...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/canon-eos-1500d-dslr-camera-body-18-55-mm-ii-lens/p/itm033175ceb4ddd?pid=DLLFAEWE22ZAERXG&lid=LSTDLLFAEWE22ZAERXGAHOJFJ&marketplace=FLIPKART&q=professional+camera&store=jek%2Fp31&srno=s_1_2&otracker=search&fm=search-autosuggest&iid=511a0959-d18d-4dcf-aa28-6c34874afd05.DLLFAEWE22ZAERXG.SEARCH&ppt=sp&ppn=sp&ssid=ih2m6bdgnk0000001653816341889&qH=43a1f7122e7538f4'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div[7]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,189,1):
    
    page_url = "https://www.flipkart.com/canon-eos-1500d-dslr-camera-body-18-55-mm-ii-lens/product-reviews/itm033175ceb4ddd?pid=DLLFAEWE22ZAERXG&lid=LSTDLLFAEWE22ZAERXGAHOJFJ&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=1800
r = [i[0] for i in element_list[ : R]]

RS=1800
rs = [i[1] for i in element_list[ : RS]]

FR=1800
fr = [i[2] for i in element_list[ : FR]]

camera1=pd.DataFrame()
camera1['Rating']=r
camera1['Review_Summary']=rs
camera1['Full_Review']=fr

# %%
Product_Name = 'Canon EOS 1500D DSLR Camera Body+ 18-55 mm IS II Lens'

# %%
camera1['Product_Name'] = Product_Name
camera1
# Out:
#      Rating       Review_Summary  \
# 0         4          Really Nice
# 1         5  Best in the market!
# 2         4            Very Good
# 3         5        Great product
# 4         5            Wonderful
# ...     ...                  ...
# 1795      5    Terrific purchase
# 1796      4           Delightful
# 1797      5       Simply awesome
# 1798      5  Best in the market!
# 1799      4            Very Good
#
#                                             Full_Review  \
# 0     Best Camera For the Beginners... Totally Loved...
# 1     This is my first Canon eos 1500d Camera and I'...
# 2     This is an awesome camera only good for photos...
# 3     I am reviewing this product after two years of...
# 4     Excellent product packaging that comes with fa...
# ...                                                 ...
# 1795  Awesome product for someone like me who likes ...
# 1796  Good product, I'd say it is the best entry lev...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/nikon-d7500-dslr-camera-body-18-140-mm-lens/p/itme57c2bb8a03cd?pid=DLLFCKK6GET9EEDC&lid=LSTDLLFCKK6GET9EEDCJXDOAU&marketplace=FLIPKART&q=camera&store=jek%2Fp31%2Ftrv&srno=s_1_1&otracker=search&fm=search-autosuggest&iid=55d58fd3-231c-4e56-920c-1a75c62fb5a8.DLLFCKK6GET9EEDC.SEARCH&ppt=browse&ppn=browse&ssid=e31d4ylx9s0000001653817011406&qH=dd6d2dcc679d12b9'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div[6]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,10,1):
    
    page_url = "https://www.flipkart.com/nikon-d7500-dslr-camera-body-18-140-mm-lens/product-reviews/itme57c2bb8a03cd?pid=DLLFCKK6GET9EEDC&lid=LSTDLLFCKK6GET9EEDCJXDOAU&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=90
r = [i[0] for i in element_list[ : R]]

RS=90
rs = [i[1] for i in element_list[ : RS]]

FR=90
fr = [i[2] for i in element_list[ : FR]]

camera2=pd.DataFrame()
camera2['Rating']=r
camera2['Review_Summary']=rs
camera2['Full_Review']=fr

# %%
Product_Name = 'NIKON D7500 DSLR Camera Body with 18-140 mm Lens'

# %%
camera2['Product_Name'] = Product_Name
camera2
# Out:
#    Rating                   Review_Summary  \
# 0       5                        Fabulous!
# 1       5                        Brilliant
# 2       4                  Value-for-money
# 3       5  An absolute beast in its range.
# 4       5                 Excelent Product
# ..    ...                              ...
# 85      4                       Delightful
# 86      5  Worthy upgrade from Nikon D5100
# 87      5            Mind-blowing purchase
# 88      4                  Worth the money
# 89      5                    Great product
#
#                                           Full_Review  \
# 0   The best camera for someone just getting into ...
# 1   One of the finest Dslr camera i hv ever seen.....
# 2   Nikon D7500 is a semi-professional camera buil...
# 3   Incredible camera. Perfect for serious hobbyis...
# 4   I needed to replace my 7200 (it broke) and deb...
# ..                                                ...
# 85  Really good camera, one of the best APS-C in t...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/hp-deskjet-ink-advantage-2135-all-in-one-printer/p/itme9ygvtsds9meh?pid=PRNE9YGV6MRXPEKG&lid=LSTPRNE9YGV6MRXPEKGVSHVBE&marketplace=FLIPKART&store=6bo%2Ftia%2Fffn%2Ft64&srno=b_2_58&otracker=browse&fm=search-autosuggest&iid=1b28c1dd-5277-4d2f-bf6d-5be7c22ee453.PRNE9YGV6MRXPEKG.SEARCH&ppt=browse&ppn=browse'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div/div/div[5]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,217,1):
    
    page_url = "https://www.flipkart.com/hp-deskjet-ink-advantage-2135-all-in-one-printer/product-reviews/itme9ygvtsds9meh?pid=PRNE9YGV6MRXPEKG&lid=LSTPRNE9YGV6MRXPEKGVSHVBE&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=2000
r = [i[0] for i in element_list[ : R]]

RS=2000
rs = [i[1] for i in element_list[ : RS]]

FR=2000
fr = [i[2] for i in element_list[ : FR]]

printer=pd.DataFrame()
printer['Rating']=r
printer['Review_Summary']=rs
printer['Full_Review']=fr

# %%
Product_Name = 'HP DeskJet Ink Advantage 2135 All-in-One Printer'

# %%
printer['Product_Name'] = Product_Name
printer
# Out:
#      Rating                        Review_Summary  \
# 0         4  Probably the best in its price range
# 1         4                       Value-for-money
# 2         5                             Excellent
# 3         5                             Excellent
# 4         4        HP 2135:- ALL YOU NEED TO KNOW
# ...     ...                                   ...
# 1939      4        HP 2135:- ALL YOU NEED TO KNOW
# 1940      5                      Value for money.
# 1941      4                           Pretty good
# 1942      4                         Great Printer
# 1943      5   Buy it. it is a really good printer
#
#                                             Full_Review  \
# 0     First of all thanks to Flipkart for the quick ...
# 1     HP 2135 is really superb printer. No doubt, u ...
# 2     Best printer for home purpose undoubtedly... +...
# 3     Its and awesome printer and very easy to opera...
# 4     Hi,\nDear Fellow Online Shoppers,\nNowadays wi...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/canon-g3012-multi-function-wifi-color-printer-color-page-cost-0-21-rs-black-0-09-borderless-printing/p/itmf2qc6hhx4pkua?pid=PRNF2QC6BX5M9NAJ&lid=LSTPRNF2QC6BX5M9NAJGZLEW6&marketplace=FLIPKART&store=6bo%2Ftia%2Fffn%2Ft64&srno=b_2_55&otracker=browse&fm=search-autosuggest&iid=1b28c1dd-5277-4d2f-bf6d-5be7c22ee453.PRNF2QC6BX5M9NAJ.SEARCH&ppt=browse&ppn=browse'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[7]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,101,1):
    
    page_url = "https://www.flipkart.com/canon-g3012-multi-function-wifi-color-printer-color-page-cost-0-21-rs-black-0-09-borderless-printing/product-reviews/itmf2qc6hhx4pkua?pid=PRNF2QC6BX5M9NAJ&lid=LSTPRNF2QC6BX5M9NAJGZLEW6&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=1000
r = [i[0] for i in element_list[ : R]]

RS=1000
rs = [i[1] for i in element_list[ : RS]]

FR=1000
fr = [i[2] for i in element_list[ : FR]]

printer1=pd.DataFrame()
printer1['Rating']=r
printer1['Review_Summary']=rs
printer1['Full_Review']=fr

# %%
Product_Name = 'Canon G3012 Multi-function WiFi Color Printer (Color Page Cost: 0.21 Rs. | Black Page Cost: 0.09 Rs. | Borderless Printing)'

# %%
printer1['Product_Name'] = Product_Name
printer1
# Out:
#     Rating   Review_Summary  \
# 0        4       Delightful
# 1        5   Simply awesome
# 2        5    Great product
# 3        5         Terrific
# 4        5        Excellent
# ..     ...              ...
# 995      4  Value-for-money
# 996      5           Super!
# 997      4      Good choice
# 998      4      Really Nice
# 999      4      Good choice
#
#                                            Full_Review  \
# 0    Canon G3012 is the same as G3010 but with two ...
# 1    Very Nice Product\nPrinter is fast and smooth ...
# 2    Superb printer. Easy to install. During this C...
# 3    After 1 month usage review\nI search for a goo...
# 4    Great purchace\nValue for money Product. Go fo...
# ..                                                 ...
# 995  Good printer as reasonable price. Quality of p...
# 996  Good Printer I use just 1 Week it's good quali...
# 997  Have been using this printer for last 2 weeks ...
# 998  I have been using Epson's L555 for close to 5 ...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/epson-l130-single-function-inkjet-printer/p/itme7cbc47zy6zfq?pid=PRNE7CBCKRSXMFKY&lid=LSTPRNE7CBCKRSXMFKYIKXXAN&marketplace=FLIPKART&store=6bo%2Ftia%2Fffn%2Ft64&srno=b_1_4&otracker=browse&fm=search-autosuggest&iid=5c72d3d9-639d-42da-ad0b-894635616334.PRNE7CBCKRSXMFKY.SEARCH&ppt=browse&ppn=browse&ssid=ie2jtm33ps0000001653817929045'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div[9]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,58,1):
    
    page_url = "https://www.flipkart.com/epson-l130-single-function-inkjet-printer/product-reviews/itme7cbc47zy6zfq?pid=PRNE7CBCKRSXMFKY&lid=LSTPRNE7CBCKRSXMFKYIKXXAN&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=500
r = [i[0] for i in element_list[ : R]]

RS=500
rs = [i[1] for i in element_list[ : RS]]

FR=500
fr = [i[2] for i in element_list[ : FR]]

printer2=pd.DataFrame()
printer2['Rating']=r
printer2['Review_Summary']=rs
printer2['Full_Review']=fr

# %%
Product_Name = 'Epson L130 Single Function Inkjet Printer'

# %%
printer2['Product_Name'] = Product_Name
printer2
# Out:
#     Rating  Review_Summary                                        Full_Review  \
# 0        4       Very Good  Very good Value for Money. Print quality reall...
# 1        3  Decent product  good printer for printing document.photo print...
# 2        5          Super!  After 3 months' use of this printer, I can say...
# 3        5       Must buy!  Awesome printing..Nice speed as well as look.....
# 4        5       Must buy!  Excellent printer. color prints are of studio ...
# ..     ...             ...                                                ...
# 495      4     Good choice  I bought it for office it's nice for office pu...
# 496      4     Pretty good  Great purchase ..The packing was of top qualit...
# 497      5       Excellent  Inovative\nThe printer was working very finely...
# 498      5          Super!  Good product. Good quality printing for office...
# 499      5       Wonderful  Best printer for home use. The installation is...
#
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/dell-18-5-inch-hd-led-backlit-tn-panel-monitor-d1918h/p/itmewm8z6awyx9rr?pid=MONEWM8ZKY38PWVP&lid=LSTMONEWM8ZKY38PWVPYRSDVB&marketplace=FLIPKART&store=6bo%2Fg0i%2F9no&srno=b_1_5&otracker=browse&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_3_L2_view-all&fm=search-autosuggest&iid=e6b9c862-5841-42a1-a1af-efef1f1726ee.MONEWM8ZKY38PWVP.SEARCH&ppt=browse&ppn=browse&ssid=7komqx8zc00000001653818988128'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[7]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,84,1):
    
    page_url = "https://www.flipkart.com/dell-18-5-inch-hd-led-backlit-tn-panel-monitor-d1918h/product-reviews/itmewm8z6awyx9rr?pid=MONEWM8ZKY38PWVP&lid=LSTMONEWM8ZKY38PWVPYRSDVB&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=700
r = [i[0] for i in element_list[ : R]]

RS=700
rs = [i[1] for i in element_list[ : RS]]

FR=700
fr = [i[2] for i in element_list[ : FR]]

monitor=pd.DataFrame()
monitor['Rating']=r
monitor['Review_Summary']=rs
monitor['Full_Review']=fr

# %%
Product_Name = 'DELL 18.5 inch HD LED Backlit TN Panel Monitor (D1918H)'

# %%
monitor['Product_Name'] = Product_Name
monitor
# Out:
#     Rating   Review_Summary  \
# 0        4      Good choice
# 1        4  Value-for-money
# 2        5    Great product
# 3        5        Must buy!
# 4        4        Wonderful
# ..     ...              ...
# 695      5    Great product
# 696      5        Must buy!
# 697      4        Wonderful
# 698      4        Wonderful
# 699      5          Awesome
#
#                                            Full_Review  \
# 0    Very Good Product. Good Packaging.\nThe Dell q...
# 1    4.5/5\n\nWow.. what a nice product\nI ❤️ it.\n...
# 2    Great product from Dell . It's budget friendly...
# 3    Good product by Dell and Flipkart. It has both...
# 4    Its a very good product... Good build quality....
# ..                                                 ...
# 695  Great product from Dell . It's budget friendly...
# 696  Good product by Dell and Flipkart. It has both...
# 697  Its a very good product... Good build quality....
# 698  This is a great monitor , very clear pictures ...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/acer-19-5-inch-hd-led-backlit-tn-panel-monitor-v206hql/p/itmeygcwhszg2vfh?pid=MONEYGCHK5GHSN6B&lid=LSTMONEYGCHK5GHSN6BZGY24X&marketplace=FLIPKART&store=6bo%2Fg0i%2F9no&srno=b_1_21&otracker=browse&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_3_L2_view-all&fm=search-autosuggest&iid=cc2dd0b4-6d0c-44d0-92fb-9315fdb6d3da.MONEYGCHK5GHSN6B.SEARCH&ppt=browse&ppn=browse&ssid=7komqx8zc00000001653818988128'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[7]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,265,1):
    
    page_url = "https://www.flipkart.com/acer-19-5-inch-hd-led-backlit-tn-panel-monitor-v206hql/product-reviews/itmeygcwhszg2vfh?pid=MONEYGCHK5GHSN6B&lid=LSTMONEYGCHK5GHSN6BZGY24X&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=2600
r = [i[0] for i in element_list[ : R]]

RS=2600
rs = [i[1] for i in element_list[ : RS]]

FR=2600
fr = [i[2] for i in element_list[ : FR]]

monitor1=pd.DataFrame()
monitor1['Rating']=r
monitor1['Review_Summary']=rs
monitor1['Full_Review']=fr

# %%
Product_Name = 'acer 19.5 inch HD+ LED Backlit TN Panel Monitor (V206HQL)'

# %%
monitor1['Product_Name'] = Product_Name
monitor1
# Out:
#      Rating                         Review_Summary  \
# 0         4                             Delightful
# 1         3                         Medium quality
# 2         5                         Simply awesome
# 3         5                     Highly recommended
# 4         3                                   Fair
# ...     ...                                    ...
# 2595      4                           Nice product
# 2596      5                      Worth every penny
# 2597      4  Awesome Product.......worth the money
# 2598      5                   Acer is Ace Monitor!
# 2599      5                     Highly recommended
#
#                                             Full_Review  \
# 0     good product , sound need to be improved , sou...
# 1     Pros - Slim border line style. Lightweight & c...
# 2     The product was great I am loving it and it's ...
# 3     Amazing work good quality display mind-blowing...
# 4     I am little bit angry. This is LCD Monitor not...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/lg-24-inch-full-hd-led-backlit-ips-panel-white-colour-monitor-24mk600m/p/itmfb6jq2jgffrtj?pid=MONFB6JQFJEP7BZX&lid=LSTMONFB6JQFJEP7BZXLEIFM1&marketplace=FLIPKART&store=6bo%2Fg0i%2F9no&srno=b_1_9&otracker=browse&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_3_L2_view-all&fm=search-autosuggest&iid=cc2dd0b4-6d0c-44d0-92fb-9315fdb6d3da.MONFB6JQFJEP7BZX.SEARCH&ppt=browse&ppn=browse&ssid=7komqx8zc00000001653818988128'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[8]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,111,1):
    
    page_url = "https://www.flipkart.com/lg-24-inch-full-hd-led-backlit-ips-panel-white-colour-monitor-24mk600m/product-reviews/itmfb6jq2jgffrtj?pid=MONFB6JQFJEP7BZX&lid=LSTMONFB6JQFJEP7BZXLEIFM1&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=1000
r = [i[0] for i in element_list[ : R]]

RS=1000
rs = [i[1] for i in element_list[ : RS]]

FR=1000
fr = [i[2] for i in element_list[ : FR]]

monitor2=pd.DataFrame()
monitor2['Rating']=r
monitor2['Review_Summary']=rs
monitor2['Full_Review']=fr

# %%
Product_Name = 'LG 24 inch Full HD LED Backlit IPS Panel White Colour Monitor (24MK600M)'

# %%
monitor2['Product_Name'] = Product_Name
monitor2
# Out:
#     Rating        Review_Summary  \
# 0        5             Just wow!
# 1        4  Good quality product
# 2        4       Worth the money
# 3        5        Classy product
# 4        4  Good quality product
# ..     ...                   ...
# 995      5                Super!
# 996      5        Simply awesome
# 997      5                Super!
# 998      5        Classy product
# 999      4           Pretty good
#
#                                            Full_Review  \
# 0    I bought this monitor after so much research o...
# 1    Monitor is great on its own but it wasn't a wo...
# 2    Color = 99%\nBlack = 70%\nThis monitor is bett...
# 3    Pros: good price to quality ratio if you get i...
# 4    Nice monitor features are fully loaded.\nPros\...
# ..                                                 ...
# 995  Best monitor brand in this price range. 75hrtz...
# 996  Exactly as i hoped it to be, deeper dark and b...
# 997  Bought it for WFH. It's an amazing purchase. T...
# ...

# %%
# Get The Webpage
url = 'https://www.flipkart.com/sony-sa-d40-80-w-bluetooth-home-theatre/p/itmfy95dvfgcbnsd?pid=ACCFY95D3FRZTWH5&lid=LSTACCFY95D3FRZTWH5WA1KBC&marketplace=FLIPKART&q=home+theatre&store=0pm%2F0o7&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_2_9_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_9_na_na_na&fm=search-autosuggest&iid=e0ee247c-c5cb-4123-ab8e-e17fb03f0736.ACCFY95D3FRZTWH5.SEARCH&ppt=sp&ppn=sp&ssid=kxm9fmvye80000001653819281094&qH=0009304d99a2e8cf'
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div[7]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,434,1):
    
    page_url = "https://www.flipkart.com/sony-sa-d40-80-w-bluetooth-home-theatre/product-reviews/itmfy95dvfgcbnsd?pid=ACCFY95D3FRZTWH5&lid=LSTACCFY95D3FRZTWH5WA1KBC&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=4000
r = [i[0] for i in element_list[ : R]]

RS=4000
rs = [i[1] for i in element_list[ : RS]]

FR=4000
fr = [i[2] for i in element_list[ : FR]]

hometheatre=pd.DataFrame()
hometheatre['Rating']=r
hometheatre['Review_Summary']=rs
hometheatre['Full_Review']=fr

# %%
Product_Name = 'SONY SA-D40 80 W Bluetooth Home Theatre'

# %%
hometheatre['Product_Name'] = Product_Name
hometheatre
# Out:
#      Rating      Review_Summary  \
# 0         5      Simply awesome
# 1         5      Simply awesome
# 2         5           Just wow!
# 3         3        Nice product
# 4         5            Terrific
# ...     ...                 ...
# 3459      3        Nice product
# 3460      5            Terrific
# 3461      5              Super!
# 3462      5  Highly recommended
# 3463      5            Not good
#
#                                             Full_Review  \
# 0     very nice sound quality। Sony is Sony । valuab...
# 1     sony D40 80 waat home theatre is so awsm..I bo...
# 2     nice product awesome bass sound quality supb. ...
# 3     1. Bass is very powerful\n2.sound clarity is a...
# 4     it's Really Awsome Product , I Satisfied too m...
# ...                                                 ...
# 3459  1. Bass is very powerful\n2.sound clarity is a...
# 3460  it's Really Awsome Product , I Satisfied too m...
# 3461  it is awesome and good for inhouse party. you ...
# ...

# %%
# Get The Webpage
url="https://www.flipkart.com/philips-spa4040b-94-45-w-bluetooth-home-theatre/p/itmebd117d83f261?pid=ACCEEYGPY99TKE8Q&lid=LSTACCEEYGPY99TKE8QKTFP19&marketplace=FLIPKART&q=home+theatre&store=0pm%2F0o7&srno=s_1_4&otracker=AS_QueryStore_OrganicAutoSuggest_2_9_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_9_na_na_na&fm=search-autosuggest&iid=e0ee247c-c5cb-4123-ab8e-e17fb03f0736.ACCEEYGPY99TKE8Q.SEARCH&ppt=sp&ppn=sp&qH=0009304d99a2e8cf"
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[6]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,376,1):
    
    page_url = "https://www.flipkart.com/philips-spa4040b-94-45-w-bluetooth-home-theatre/product-reviews/itmebd117d83f261?pid=ACCEEYGPY99TKE8Q&lid=LSTACCEEYGPY99TKE8QKTFP19&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=3500
r = [i[0] for i in element_list[ : R]]

RS=3500
rs = [i[1] for i in element_list[ : RS]]

FR=3500
fr = [i[2] for i in element_list[ : FR]]

hometheatre1=pd.DataFrame()
hometheatre1['Rating']=r
hometheatre1['Review_Summary']=rs
hometheatre1['Full_Review']=fr

# %%
Product_Name = 'PHILIPS SPA4040B/94 45 W Bluetooth Home Theatre'

# %%
hometheatre1['Product_Name'] = Product_Name
hometheatre1
# Out:
#      Rating                             Review_Summary  \
# 0         4                       Good quality product
# 1         5                                  Excellent
# 2         5                                  Fabulous!
# 3         5                             #VALUEforMONEY
# 4         5                                  Excellent
# ...     ...                                        ...
# 3495      4                            Worth the money
# 3496      5                                  Wonderful
# 3497      5                                    Awesome
# 3498      4                       Good quality product
# 3499      5  Best 5.1 speakers in this price range !!!
#
#                                             Full_Review  \
# 0     Good product from my side. Very good clear sou...
# 1     Wow, excellent Bass & Super Sound Quality, Hig...
# 2     It's an Awesome Product at Reasonable price an...
# 3     Great Value for money !! Good product + Great ...
# ...

# %%
# Get The Webpage
url="https://www.flipkart.com/panasonic-sc-ht460gw-k-100-w-bluetooth-home-theatre/p/itm66cf5b5135ea5?pid=ACCGFGC6YZZDVFHG&lid=LSTACCGFGC6YZZDVFHGFJRBPO&marketplace=FLIPKART&q=home+theatre&store=0pm%2F0o7&srno=s_1_20&otracker=AS_QueryStore_OrganicAutoSuggest_2_9_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_9_na_na_na&fm=search-autosuggest&iid=e0ee247c-c5cb-4123-ab8e-e17fb03f0736.ACCGFGC6YZZDVFHG.SEARCH&ppt=sp&ppn=sp&qH=0009304d99a2e8cf"
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[4]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,118,1):
    
    page_url = "https://www.flipkart.com/panasonic-sc-ht460gw-k-100-w-bluetooth-home-theatre/product-reviews/itm66cf5b5135ea5?pid=ACCGFGC6YZZDVFHG&lid=LSTACCGFGC6YZZDVFHGFJRBPO&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=1000
r = [i[0] for i in element_list[ : R]]

RS=1000
rs = [i[1] for i in element_list[ : RS]]

FR=1000
fr = [i[2] for i in element_list[ : FR]]

hometheatre2=pd.DataFrame()
hometheatre2['Rating']=r
hometheatre2['Review_Summary']=rs
hometheatre2['Full_Review']=fr

# %%
Product_Name = 'Panasonic SC-HT460GW-K 100 W Bluetooth Home Theatre'

# %%
hometheatre2['Product_Name'] = Product_Name
hometheatre2
# Out:
#     Rating   Review_Summary  \
# 0        5         Terrific
# 1        5           Super!
# 2        5   Classy product
# 3        5        Brilliant
# 4        4  Worth the money
# ..     ...              ...
# 995      5   Classy product
# 996      4      Pretty good
# 997      5    Great product
# 998      5        Must buy!
# 999      5        Must buy!
#
#                                            Full_Review  \
# 0    Beautiful product, great piece of engineering!...
# 1    Flipkart is practically the best and genuine o...
# 2    Well for the price tag it's VFM. At par with S...
# 3    Good product in this price range.bass and soun...
# 4    After a month long research with the price con...
# ..                                                 ...
# 995  Just go for it man 💯.\nModel : Panasonic SC-HT...
# 996  Audio quality is super FM signals super Blue t...
# 997  Loved it.♥️\nBest in this price range.\nIf you...
# 998  Absolutely great product from Panasonic Japane...
# ...

# %%
# Get The Webpage
url="https://www.flipkart.com/tp-link-archer-c20-ac-wifi-750-mbps-wireless-router/p/itmc7d65de184124?pid=RTRE8GKF2CUJ2GNN&lid=LSTRTRE8GKF2CUJ2GNNA9BJX3&marketplace=FLIPKART&q=router&store=6bo%2F2a2&srno=s_1_2&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&fm=search-autosuggest&iid=af7f8073-df96-450f-ae57-fb4dc0f41f8a.RTRE8GKF2CUJ2GNN.SEARCH&ppt=sp&ppn=sp&ssid=cc12tg7uq80000001653819358362&qH=f3395cd54cf857dd"
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div[9]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,370,1):
    
    page_url = "https://www.flipkart.com/tp-link-archer-c20-ac-wifi-750-mbps-wireless-router/product-reviews/itmc7d65de184124?pid=RTRE8GKF2CUJ2GNN&lid=LSTRTRE8GKF2CUJ2GNNA9BJX3&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=3500
r = [i[0] for i in element_list[ : R]]

RS=3500
rs = [i[1] for i in element_list[ : RS]]

FR=3500
fr = [i[2] for i in element_list[ : FR]]

router=pd.DataFrame()
router['Rating']=r
router['Review_Summary']=rs
router['Full_Review']=fr

# %%
Product_Name = 'TP-Link Archer C20 AC WiFi 750 MBPS Wireless Router'

# %%
router['Product_Name'] = Product_Name
router
# Out:
#      Rating                                    Review_Summary  \
# 0         5                                 Worth every penny
# 1         5                                         Wonderful
# 2         5  Got a good router after doing a lot of research!
# 3         5                                  Very Good Router
# 4         4                                   Worth the money
# ...     ...                                               ...
# 3495      5             Excellent Product at Reasonable Price
# 3496      5                                          Terrific
# 3497      5                                         Wonderful
# 3498      5                                           Awesome
# 3499      4                              Good quality product
#
#                                             Full_Review  \
# 0     This is the best WiFi router in this price ran...
# 1     Just fabulous performance, i am very glad to c...
# ...

# %%
# Get The Webpage
url="https://www.flipkart.com/tenda-f3-wireless-router-300-mbps/p/itmebg9ccwkmt4zs?pid=RTREBG9CJ7HHSHGJ&lid=LSTRTREBG9CJ7HHSHGJJ940LU&marketplace=FLIPKART&q=router&store=6bo%2F2a2&srno=s_1_8&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&fm=search-autosuggest&iid=af7f8073-df96-450f-ae57-fb4dc0f41f8a.RTREBG9CJ7HHSHGJ.SEARCH&ppt=sp&ppn=sp&qH=f3395cd54cf857dd"
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[6]/div[7]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,108,1):
    
    page_url = "https://www.flipkart.com/tenda-f3-wireless-router-300-mbps/product-reviews/itmebg9ccwkmt4zs?pid=RTREBG9CJ7HHSHGJ&lid=LSTRTREBG9CJ7HHSHGJJ940LU&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=1000
r = [i[0] for i in element_list[ : R]]

RS=1000
rs = [i[1] for i in element_list[ : RS]]

FR=1000
fr = [i[2] for i in element_list[ : FR]]

router1=pd.DataFrame()
router1['Rating']=r
router1['Review_Summary']=rs
router1['Full_Review']=fr

# %%
Product_Name = 'TENDA F3 Wireless Router 300 Mbps Wireless Router'

# %%
router1['Product_Name'] = Product_Name
router1
# Out:
#     Rating                             Review_Summary  \
# 0        5                          Worth every penny
# 1        5  Excellent Range & Speed for 2-Story House
# 2        5        Obsolete product in false packaging
# 3        5                         NOT A GOOD CHOICE.
# 4        5                          Worth every penny
# ..     ...                                        ...
# 851      5                         NOT A GOOD CHOICE.
# 852      5                          Worth every penny
# 853      5                             Classy product
# 854      5                                  Brilliant
# 855      5               Excellent product from Tenda
#
#                                            Full_Review  \
# 0    Best buy for the price. The range is excellent...
# 1    at this price point of view , I'm satisfied wi...
# 2    The product explains 300 mbps transfer speeds ...
# 3    I have purchased this Router for my house. A 9...
# ...

# %%
# Get The Webpage
url="https://www.flipkart.com/d-link-dir-825-ac1200-wi-fi-gigabit-1200-mbps-wireless-router/p/itmfypg6g2cxdxcy?pid=RTRFYP3GSRTXHHRQ&lid=LSTRTRFYP3GSRTXHHRQ0Q5ZT5&marketplace=FLIPKART&q=router&store=6bo%2F2a2&srno=s_1_12&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&fm=search-autosuggest&iid=af7f8073-df96-450f-ae57-fb4dc0f41f8a.RTRFYP3GSRTXHHRQ.SEARCH&ppt=sp&ppn=sp&qH=f3395cd54cf857dd"
driver.get(url)

# %%
# Clicking All Reviews Using Absolute Xpath Function -
All = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div[8]/div/a")
# Button Will Get Clicked
All.click()

# %%
element_list = []
  
for page in range(1,101,1):
    
    page_url = "https://www.flipkart.com/d-link-dir-825-ac1200-wi-fi-gigabit-1200-mbps-wireless-router/product-reviews/itmfypg6g2cxdxcy?pid=RTRFYP3GSRTXHHRQ&lid=LSTRTRFYP3GSRTXHHRQ0Q5ZT5&marketplace=FLIPKART&page=1"+ str(page)
    rating = driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    review_summary = driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    full_review = driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    for i in range(len(rating)):
        element_list.append([rating[i].text, review_summary[i].text, full_review[i].text])

R=1000
r = [i[0] for i in element_list[ : R]]

RS=1000
rs = [i[1] for i in element_list[ : RS]]

FR=1000
fr = [i[2] for i in element_list[ : FR]]

router2=pd.DataFrame()
router2['Rating']=r
router2['Review_Summary']=rs
router2['Full_Review']=fr

# %%
Product_Name = 'D-Link DIR-825 AC1200 Wi-Fi Gigabit 1200 Mbps Wireless Router'

# %%
router2['Product_Name'] = Product_Name
router2
# Out:
#     Rating        Review_Summary  \
# 0        3             Just okay
# 1        5   Best in the market!
# 2        5             Brilliant
# 3        4  Good quality product
# 4        5     Terrific purchase
# ..     ...                   ...
# 995      5             Excellent
# 996      5             Wonderful
# 997      5             Excellent
# 998      5         Great product
# 999      5             Brilliant
#
#                                            Full_Review  \
# 0    Yes it does provide good speeds at 5Ghz but th...
# 1    Its best i can say. I work in IT, has experien...
# 2    It's a good router.\nJust Plug and Play.\nHard...
# 3    Easy to install, and works fine with an old Ma...
# 4    Baught this router during the lockdown. And us...
# ..                                                 ...
# 995  1. Speed is well transferred.\n2. Cable provid...
# 996  Best router I have ever purchased. It has so m...
# 997  Honest review.... Must read....\nIts a very am...
# ...

# %%
RatingsPrediction=pd.concat([lap,lap1,lap2,headphone,headphone1,headphone2,mobile,mobile1,mobile2,smartwatch,smartwatch1,smartwatch2,camera,camera1,camera2,printer,printer1,printer2,monitor,monitor1,monitor2,hometheatre,hometheatre1,hometheatre2,router,router1,router2])
RatingsPrediction
# Out:
#     Rating         Review_Summary  \
# 0        5  Mind-blowing purchase
# 1        4              Wonderful
# 2        5         Simply awesome
# 3        5    Best in the market!
# 4        5  Mind-blowing purchase
# ..     ...                    ...
# 995      5              Excellent
# 996      5              Wonderful
# 997      5              Excellent
# 998      5          Great product
# 999      5              Brilliant
#
#                                            Full_Review  \
# 0    Pros :-\nRyzen 5 (5600h) beast 😍\nDisplay is a...
# 1    I have used this laptop for one week and my ob...
# 2    If you're looking for a best budget gaming lap...
# 3    No compromise in performance and the thermals ...
# 4    1)Trust me guys this is awesome Laptop 💻 in bu...
# ..                                                 ...
# 995  1. Speed is well transferred.\n2. Cable provid...
# 996  Best router I have ever purchased. It has so m...
# ...

# %%
RatingsPrediction.to_excel("RatingsPredictionData.xlsx",sheet_name='RatingsPrediction')

# %% [markdown]
# # Thanks...!!!
