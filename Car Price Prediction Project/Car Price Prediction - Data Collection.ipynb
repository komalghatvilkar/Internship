# %% [markdown]
# # Data Collection

# %% [markdown]
# # Cars24

# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

import warnings
warnings.filterwarnings("ignore")

from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/99.0.4844.51/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\HP\.wdm\drivers\chromedriver\win32\99.0.4844.51]

# %%
url = 'https://www.cars24.com/?utm_source=google&utm_medium=cpc&utm_campaign=brand&utm_source=google&utm_medium=adwords&utm_keyword=cars24&utm_matchtype=e&utm_device=c&adgroup_id=127158970287&campaign_id=1821263948&gclid=EAIaIQobChMI-JKC09Pi9gIVN5hmAh2wgwcSEAAYASAAEgItD_D_BwE&gclid=EAIaIQobChMI-JKC09Pi9gIVN5hmAh2wgwcSEAAYASAAEgItD_D_BwE'
driver.get(url)

# %%
cars=driver.find_element_by_xpath("/html/body/div[1]/div[5]/div/div/div[2]/button")
cars.click()

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,15000)")

# %%
b = []
brand= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in brand:
    b.append(i.text)
y = []
year= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in year:
    y.append(i.text)
t = []
trans= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[1]/div/p/span")
for i in trans:
    t.append(i.text)    
m = []
model= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/p")
for i in model:
    m.append(i.text)
k = []
kilometers= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[1]")
for i in kilometers:
    k.append(i.text)
o = []
owner= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[2]")
for i in owner:
    o.append(i.text)
f = []
fuel= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[3]")
for i in fuel:
    f.append(i.text)
e = []
emi= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[1]/strong")
for i in emi:
    e.append(i.text.replace('₹',''))
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[2]/span")
for i in price:
    p.append(i.text.replace('₹',''))
d = []
downpayment= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[3]/span")
for i in downpayment:
    d.append(i.text)

time.sleep(2)        
#creating dataframe
df=pd.DataFrame({'Brand':b,'Model':m,'Year Of Purchase':y,'Transmission':t,'Kilometers Drive Till Now':k,'Owner':o,'Feul':f,'EMI':e,'Price Of Car':p,'Downpayment':d})

# %%
Location = 'New Delhi'

# %%
df['Location'] = Location

# %%
df
# Out:
#                        Brand                       Model  \
# 0       2014 Maruti Alto K10                  VXI Manual
# 1     2015 Hyundai Grand i10       MAGNA 1.1 CRDI Manual
# 2    2014 Maruti Swift Dzire            VDI BS IV Manual
# 3          2015 Maruti Swift              VDI ABS Manual
# 4       2019 Maruti Alto K10                  VXI Manual
# ..                       ...                         ...
# 772       2013 Toyota Innova   2.5 GX 7 STR BS IV Manual
# 773   2019 Hyundai Elite i20  1.2 MAGNA PLUS VTVT Manual
# 774       2020 Ford Ecosport    1.5 AMBIENTE TDCI Manual
# 775        2019 Renault Kwid                  RXL Manual
# 776       2018 Maruti Baleno        DELTA 1.2 K12 Manual
#
#             Year Of Purchase Transmission Kilometers Drive Till Now  \
# 0       2014 Maruti Alto K10       Manual                 40,562 km
# 1     2015 Hyundai Grand i10       Manual                 62,491 km
# 2    2014 Maruti Swift Dzire       Manual                 96,978 km
# ...

# %%
loc=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p")
loc.click()

# %%
bengaluru=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[6]/span/img")
bengaluru.click()

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
b = []
brand= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in brand:
    b.append(i.text)
y = []
year= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in year:
    y.append(i.text)
t = []
trans= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[1]/div/p/span")
for i in trans:
    t.append(i.text)    
m = []
model= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/p")
for i in model:
    m.append(i.text)
k = []
kilometers= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[1]")
for i in kilometers:
    k.append(i.text)
o = []
owner= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[2]")
for i in owner:
    o.append(i.text)
f = []
fuel= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[3]")
for i in fuel:
    f.append(i.text)
e = []
emi= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[1]/strong")
for i in emi:
    e.append(i.text.replace('₹',''))
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[2]/span")
for i in price:
    p.append(i.text.replace('₹',''))
d = []
downpayment= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[3]/span")
for i in downpayment:
    d.append(i.text)

time.sleep(2)        
#creating dataframe
df1=pd.DataFrame({'Brand':b,'Model':m,'Year Of Purchase':y,'Transmission':t,'Kilometers Drive Till Now':k,'Owner':o,'Feul':f,'EMI':e,'Price Of Car':p,'Downpayment':d})

# %%
Location = 'Bengaluru'

# %%
df1['Location'] = Location

# %%
df1
# Out:
#                      Brand                  Model       Year Of Purchase  \
# 0        2017 Renault Kwid     CLIMBER 1.0 Manual      2017 Renault Kwid
# 1        2018 Maruti Swift      ZDI AMT Automatic      2018 Maruti Swift
# 2       2017 Hyundai Verna     1.6 SX VTVT Manual     2017 Hyundai Verna
# 3        2014 Maruti Swift             VXI Manual      2014 Maruti Swift
# 4    2017 Mahindra Scorpio         S6 PLUS Manual  2017 Mahindra Scorpio
# ..                     ...                    ...                    ...
# 433   2014 Maruti Alto K10             VXI Manual   2014 Maruti Alto K10
# 434       2018 Maruti Eeco           7 STR Manual       2018 Maruti Eeco
# 435   2015 Maruti Alto K10      VXI AMT Automatic   2015 Maruti Alto K10
# 436   2016 Maruti Alto K10  VXI (O) AMT Automatic   2016 Maruti Alto K10
# 437   2014 Maruti Alto K10             VXI Manual   2014 Maruti Alto K10
#
#     Transmission Kilometers Drive Till Now      Owner    Feul           EMI  \
# ...

# %%
loc1=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p")
loc1.click()

# %%
pune=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[5]/span/img")
pune.click()

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
b = []
brand= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in brand:
    b.append(i.text)
y = []
year= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in year:
    y.append(i.text)
t = []
trans= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[1]/div/p/span")
for i in trans:
    t.append(i.text)    
m = []
model= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/p")
for i in model:
    m.append(i.text)
k = []
kilometers= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[1]")
for i in kilometers:
    k.append(i.text)
o = []
owner= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[2]")
for i in owner:
    o.append(i.text)
f = []
fuel= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[3]")
for i in fuel:
    f.append(i.text)
e = []
emi= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[1]/strong")
for i in emi:
    e.append(i.text.replace('₹',''))
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[2]/span")
for i in price:
    p.append(i.text.replace('₹',''))
d = []
downpayment= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[3]/span")
for i in downpayment:
    d.append(i.text)

time.sleep(2)        
#creating dataframe
df2=pd.DataFrame({'Brand':b,'Model':m,'Year Of Purchase':y,'Transmission':t,'Kilometers Drive Till Now':k,'Owner':o,'Feul':f,'EMI':e,'Price Of Car':p,'Downpayment':d})

# %%
Location = 'Pune'

# %%
df2['Location'] = Location

# %%
df2
# Out:
#                       Brand                   Model        Year Of Purchase  \
# 0    2015 Hyundai Elite i20    ASTA 1.4 CRDI Manual  2015 Hyundai Elite i20
# 1        2018 Hyundai Verna      1.6 SX VTVT Manual      2018 Hyundai Verna
# 2        2016 Maruti Baleno    DELTA 1.2 K12 Manual      2016 Maruti Baleno
# 3    2013 Hyundai Grand i10    ASTA 1.2 VTVT Manual  2013 Hyundai Grand i10
# 4        2015 Maruti Baleno     ZETA 1.2 K12 Manual      2015 Maruti Baleno
# ..                      ...                     ...                     ...
# 639      2017 Maruti Baleno    DELTA 1.2 K12 Manual      2017 Maruti Baleno
# 640       2018 Maruti Swift              LXI Manual       2018 Maruti Swift
# 641         2017 Tata Tiago  XZ 1.2 REVOTRON Manual         2017 Tata Tiago
# 642     2018 Maruti S Cross           ZETA 1.3 SHVS     2018 Maruti S Cross
# 643       2019 Maruti Dzire              VXI Manual       2019 Maruti Dzire
#
# ...

# %%
loc2=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p")
loc2.click()

# %%
mumbai=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[4]/span/img")
mumbai.click()

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
b = []
brand= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in brand:
    b.append(i.text)
y = []
year= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in year:
    y.append(i.text)
t = []
trans= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[1]/div/p/span")
for i in trans:
    t.append(i.text)    
m = []
model= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/p")
for i in model:
    m.append(i.text)
k = []
kilometers= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[1]")
for i in kilometers:
    k.append(i.text)
o = []
owner= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[2]")
for i in owner:
    o.append(i.text)
f = []
fuel= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[3]")
for i in fuel:
    f.append(i.text)
e = []
emi= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[1]/strong")
for i in emi:
    e.append(i.text.replace('₹',''))
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[2]/span")
for i in price:
    p.append(i.text.replace('₹',''))
d = []
downpayment= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[3]/span")
for i in downpayment:
    d.append(i.text)

time.sleep(2)        
#creating dataframe
df3=pd.DataFrame({'Brand':b,'Model':m,'Year Of Purchase':y,'Transmission':t,'Kilometers Drive Till Now':k,'Owner':o,'Feul':f,'EMI':e,'Price Of Car':p,'Downpayment':d})

# %%
Location = 'Mumbai'

# %%
df3['Location'] = Location

# %%
df3
# Out:
#                       Brand                        Model  \
# 0        2019 Maruti Baleno         ALPHA 1.2 K12 Manual
# 1      2019 Mahindra XUV500               W11 (O) Manual
# 2           2017 Honda Jazz              1.2 S MT Manual
# 3    2017 Hyundai Grand i10  MAGNA 1.2 KAPPA VTVT Manual
# 4    2016 Hyundai Grand i10   ASTA 1.2 KAPPA VTVT Manual
# ..                      ...                          ...
# 684    2019 Maruti Alto K10                   VXI Manual
# 685    2018 Maruti Alto 800               LXI OPT Manual
# 686  2019 Hyundai Elite i20   1.2 ASTA (O) CVT Automatic
# 687  2014 Hyundai Grand i10       SPORTS 1.2 VTVT Manual
# 688  2019 Hyundai Grand i10        MAGNA 1.2 VTVT Manual
#
#            Year Of Purchase Transmission Kilometers Drive Till Now      Owner  \
# 0        2019 Maruti Baleno       Manual                  9,489 km  1st Owner
# 1      2019 Mahindra XUV500       Manual                 47,382 km  1st Owner
# ...

# %%
loc3=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p")
loc3.click()

# %%
ahmedabad=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[10]/span/img")
ahmedabad.click()

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
b = []
brand= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in brand:
    b.append(i.text)
y = []
year= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in year:
    y.append(i.text)
t = []
trans= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[1]/div/p/span")
for i in trans:
    t.append(i.text)    
m = []
model= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/p")
for i in model:
    m.append(i.text)
k = []
kilometers= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[1]")
for i in kilometers:
    k.append(i.text)
o = []
owner= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[2]")
for i in owner:
    o.append(i.text)
f = []
fuel= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[3]")
for i in fuel:
    f.append(i.text)
e = []
emi= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[1]/strong")
for i in emi:
    e.append(i.text.replace('₹',''))
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[2]/span")
for i in price:
    p.append(i.text.replace('₹',''))
d = []
downpayment= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[3]/span")
for i in downpayment:
    d.append(i.text)

time.sleep(2)        
#creating dataframe
df4=pd.DataFrame({'Brand':b,'Model':m,'Year Of Purchase':y,'Transmission':t,'Kilometers Drive Till Now':k,'Owner':o,'Feul':f,'EMI':e,'Price Of Car':p,'Downpayment':d})

# %%
Location = 'Ahmedabad'

# %%
df4['Location'] = Location

# %%
df4
# Out:
#                       Brand                                  Model  \
# 0      2017 Maruti Alto 800                             LXI Manual
# 1          2020 Maruti Alto                             LXI Manual
# 2          2020 Maruti Alto                             VXI Manual
# 3    2018 Hyundai Grand i10                  MAGNA 1.2 VTVT Manual
# 4    2016 Hyundai Grand i10                 SPORTS 1.2 VTVT Manual
# ..                      ...                                    ...
# 380      2020 Ford Ecosport  1.5 TITANIUM PLUS TI VCT AT Automatic
# 381      2019 Maruti Baleno                   DELTA 1.2 K12 Manual
# 382         2015 Honda Brio                 1.2 S MT I VTEC Manual
# 383    2019 Maruti S PRESSO                        VXI PLUS Manual
# 384    2018 Maruti Alto 800                             VXI Manual
#
#            Year Of Purchase Transmission Kilometers Drive Till Now      Owner  \
# 0      2017 Maruti Alto 800       Manual                 75,118 km  1st Owner
# ...

# %%
loc4=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p")
loc4.click()

# %%
hyderabad=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[7]/span/img")
hyderabad.click()

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
b = []
brand= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in brand:
    b.append(i.text)
y = []
year= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in year:
    y.append(i.text)
t = []
trans= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[1]/div/p/span")
for i in trans:
    t.append(i.text)    
m = []
model= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/p")
for i in model:
    m.append(i.text)
k = []
kilometers= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[1]")
for i in kilometers:
    k.append(i.text)
o = []
owner= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[2]")
for i in owner:
    o.append(i.text)
f = []
fuel= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[3]")
for i in fuel:
    f.append(i.text)
e = []
emi= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[1]/strong")
for i in emi:
    e.append(i.text.replace('₹',''))
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[2]/span")
for i in price:
    p.append(i.text.replace('₹',''))
d = []
downpayment= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[3]/span")
for i in downpayment:
    d.append(i.text)

time.sleep(2)        
#creating dataframe
df5=pd.DataFrame({'Brand':b,'Model':m,'Year Of Purchase':y,'Transmission':t,'Kilometers Drive Till Now':k,'Owner':o,'Feul':f,'EMI':e,'Price Of Car':p,'Downpayment':d})

# %%
Location = 'Hyderabad'

# %%
df5['Location'] = Location

# %%
df5
# Out:
#                        Brand                         Model  \
# 0     2016 Hyundai Elite i20             SPORTZ 1.4 Manual
# 1         2014 Maruti Ertiga                    ZXI Manual
# 2         2018 Hyundai Verna    1.6 CRDI SX + AT Automatic
# 3            2017 Tata Tiago        XZ 1.2 REVOTRON Manual
# 4         2017 Skoda Octavia       Style 1.4 TSI MT Manual
# ..                       ...                           ...
# 120         2019 Maruti Eeco  5 STR WITH AC PLUSHTR Manual
# 121         2012 Hyundai i10           ERA 1.1 IRDE Manual
# 122          2014 Honda Brio        1.2 S MT I VTEC Manual
# 123     2018 Maruti Alto 800                    LXI Manual
# 124  2012 Maruti Swift Dzire              VDI BS IV Manual
#
#             Year Of Purchase Transmission Kilometers Drive Till Now  \
# 0     2016 Hyundai Elite i20       Manual                 51,885 km
# 1         2014 Maruti Ertiga       Manual                 67,232 km
# ...

# %%
loc5=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p")
loc5.click()

# %%
chennai=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[8]/span/img")
chennai.click()

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
b = []
brand= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in brand:
    b.append(i.text)
y = []
year= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in year:
    y.append(i.text)
t = []
trans= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[1]/div/p/span")
for i in trans:
    t.append(i.text)    
m = []
model= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/p")
for i in model:
    m.append(i.text)
k = []
kilometers= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[1]")
for i in kilometers:
    k.append(i.text)
o = []
owner= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[2]")
for i in owner:
    o.append(i.text)
f = []
fuel= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[3]")
for i in fuel:
    f.append(i.text)
e = []
emi= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[1]/strong")
for i in emi:
    e.append(i.text.replace('₹',''))
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[2]/span")
for i in price:
    p.append(i.text.replace('₹',''))
d = []
downpayment= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[3]/span")
for i in downpayment:
    d.append(i.text)

time.sleep(2)        
#creating dataframe
df6=pd.DataFrame({'Brand':b,'Model':m,'Year Of Purchase':y,'Transmission':t,'Kilometers Drive Till Now':k,'Owner':o,'Feul':f,'EMI':e,'Price Of Car':p,'Downpayment':d})

# %%
Location = 'Chennai'

# %%
df6['Location'] = Location

# %%
df6
# Out:
#                        Brand                               Model  \
# 0          2016 Renault Kwid                      RXT Opt Manual
# 1       2016 Mahindra TUV300                           T8 Manual
# 2       2016 Mahindra TUV300                           T8 Manual
# 3         2014 Hyundai Verna      FLUIDIC 1.6 SX VTVT OPT Manual
# 4       2013 Maruti Alto 800                          LXI Manual
# ..                       ...                                 ...
# 673        2019 Maruti Swift                          LXI Manual
# 674        2019 Renault Kwid  RXT 1.0 EASY-R AT OPTION Automatic
# 675      2017 Maruti Celerio                          ZXI Manual
# 676      2019 Maruti Celerio               VXI (O) AMT Automatic
# 677  2016 Maruti Wagon R 1.0                      VXI OPT Manual
#
#             Year Of Purchase Transmission Kilometers Drive Till Now  \
# 0          2016 Renault Kwid       Manual                 51,188 km
# ...

# %%
loc6=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p")
loc6.click()

# %%
kolkata=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[9]/span/img")
kolkata.click()

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
b = []
brand= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in brand:
    b.append(i.text)
y = []
year= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in year:
    y.append(i.text)
t = []
trans= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[1]/div/p/span")
for i in trans:
    t.append(i.text)    
m = []
model= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/p")
for i in model:
    m.append(i.text)
k = []
kilometers= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[1]")
for i in kilometers:
    k.append(i.text)
o = []
owner= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[2]")
for i in owner:
    o.append(i.text)
f = []
fuel= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[3]")
for i in fuel:
    f.append(i.text)
e = []
emi= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[1]/strong")
for i in emi:
    e.append(i.text.replace('₹',''))
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[2]/span")
for i in price:
    p.append(i.text.replace('₹',''))
d = []
downpayment= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[3]/span")
for i in downpayment:
    d.append(i.text)

time.sleep(2)        
#creating dataframe
df7=pd.DataFrame({'Brand':b,'Model':m,'Year Of Purchase':y,'Transmission':t,'Kilometers Drive Till Now':k,'Owner':o,'Feul':f,'EMI':e,'Price Of Car':p,'Downpayment':d})

# %%
Location = 'Kolkata'

# %%
df7['Location'] = Location

# %%
df7
# Out:
#                        Brand                              Model  \
# 0         2015 Hyundai Verna         FLUIDIC 1.6 SX CRDI Manual
# 1    2013 Maruti Wagon R 1.0                         VXI Manual
# 2        2013 Renault Duster              RXZ DIESEL 110 Manual
# 3         2014 Maruti Ertiga                         ZXI Manual
# 4               2013 Audi A4  2.0 TDI 174BHP PRM PLUS Automatic
# ..                       ...                                ...
# 271     2019 Maruti Alto 800                         LXI Manual
# 272     2017 Maruti Alto 800                         VXI Manual
# 273    2015 Mahindra Scorpio                         S10 Manual
# 274     2019 Maruti Alto 800                         VXI Manual
# 275     2013 Maruti Alto 800                         LXI Manual
#
#             Year Of Purchase Transmission Kilometers Drive Till Now  \
# 0         2015 Hyundai Verna       Manual                 47,025 km
# ...

# %%
loc7=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p")
loc7.click()

# %%
gurgaon=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[3]/span/img")
gurgaon.click()

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
b = []
brand= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in brand:
    b.append(i.text)
y = []
year= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in year:
    y.append(i.text)
t = []
trans= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[1]/div/p/span")
for i in trans:
    t.append(i.text)    
m = []
model= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/p")
for i in model:
    m.append(i.text)
k = []
kilometers= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[1]")
for i in kilometers:
    k.append(i.text)
o = []
owner= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[2]")
for i in owner:
    o.append(i.text)
f = []
fuel= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[3]")
for i in fuel:
    f.append(i.text)
e = []
emi= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[1]/strong")
for i in emi:
    e.append(i.text.replace('₹',''))
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[2]/span")
for i in price:
    p.append(i.text.replace('₹',''))
d = []
downpayment= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[3]/span")
for i in downpayment:
    d.append(i.text)

time.sleep(2)        
#creating dataframe
df8=pd.DataFrame({'Brand':b,'Model':m,'Year Of Purchase':y,'Transmission':t,'Kilometers Drive Till Now':k,'Owner':o,'Feul':f,'EMI':e,'Price Of Car':p,'Downpayment':d})

# %%
Location = 'Gurgaon'

# %%
df8['Location'] = Location

# %%
df8
# Out:
#                          Brand                       Model  \
# 0           2015 Maruti Ertiga                  ZDI Manual
# 1         2013 Toyota Fortuner           3.0 MT 4X2 Manual
# 2           2017 Ford Ecosport     1.5TITANIUM TDCI Manual
# 3      2013 Maruti Wagon R 1.0                  LXI Manual
# 4    2016 Maruti Vitara Brezza                  ZDI Manual
# ..                         ...                         ...
# 775         2015 Hyundai Verna      FLUIDIC 1.6 CRDI S (o)
# 776       2012 Volkswagen Polo  HIGHLINE1.2L PETROL Manual
# 777       2017 Maruti Alto 800                  LXI Manual
# 778            2019 Tata Tiago      XZ 1.2 REVOTRON Manual
# 779          2017 Renault Kwid          1.0 RXT Opt Manual
#
#               Year Of Purchase Transmission Kilometers Drive Till Now  \
# 0           2015 Maruti Ertiga       Manual                 52,870 km
# 1         2013 Toyota Fortuner       Manual               1,17,460 km
# ...

# %%
loc8=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p")
loc8.click()

# %%
noida=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[2]/span/img")
noida.click()

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
b = []
brand= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in brand:
    b.append(i.text)
y = []
year= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in year:
    y.append(i.text)
t = []
trans= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[1]/div/p/span")
for i in trans:
    t.append(i.text)    
m = []
model= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/p")
for i in model:
    m.append(i.text)
k = []
kilometers= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[1]")
for i in kilometers:
    k.append(i.text)
o = []
owner= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[2]")
for i in owner:
    o.append(i.text)
f = []
fuel= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[3]")
for i in fuel:
    f.append(i.text)
e = []
emi= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[1]/strong")
for i in emi:
    e.append(i.text.replace('₹',''))
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[2]/span")
for i in price:
    p.append(i.text.replace('₹',''))
d = []
downpayment= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[3]/span")
for i in downpayment:
    d.append(i.text)

time.sleep(2)        
#creating dataframe
df9=pd.DataFrame({'Brand':b,'Model':m,'Year Of Purchase':y,'Transmission':t,'Kilometers Drive Till Now':k,'Owner':o,'Feul':f,'EMI':e,'Price Of Car':p,'Downpayment':d})

# %%
Location = 'Noida'

# %%
df9['Location'] = Location

# %%
df9
# Out:
#                        Brand                       Model  \
# 0    2013 Maruti Swift Dzire            LDI BS IV Manual
# 1           2013 Maruti Ritz                  VDI Manual
# 2       2012 Maruti Alto K10                  VXI Manual
# 3     2017 Hyundai Grand i10  ASTA 1.2 KAPPA VTVT Manual
# 4         2019 Ford Ecosport     1.5TITANIUM TDCI Manual
# ..                       ...                         ...
# 783       2013 Toyota Innova   2.5 GX 7 STR BS IV Manual
# 784   2019 Hyundai Elite i20  1.2 MAGNA PLUS VTVT Manual
# 785       2020 Ford Ecosport    1.5 AMBIENTE TDCI Manual
# 786        2019 Renault Kwid                  RXL Manual
# 787       2018 Maruti Baleno        DELTA 1.2 K12 Manual
#
#             Year Of Purchase Transmission Kilometers Drive Till Now  \
# 0    2013 Maruti Swift Dzire       Manual               1,30,588 km
# 1           2013 Maruti Ritz       Manual                 55,532 km
# 2       2012 Maruti Alto K10       Manual                 72,766 km
# ...

# %%
loc9=driver.find_element_by_xpath("/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p")
loc9.click()

# %%
agra=driver.find_element_by_xpath("/html/body/div[1]/div[6]/div/div/div/div[2]/div/div/ul/div[3]/li[2]/span")
agra.click()

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
b = []
brand= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in brand:
    b.append(i.text)
y = []
year= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/h2")
for i in year:
    y.append(i.text)
t = []
trans= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[1]/div/p/span")
for i in trans:
    t.append(i.text)    
m = []
model= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div/div/p")
for i in model:
    m.append(i.text)
k = []
kilometers= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[1]")
for i in kilometers:
    k.append(i.text)
o = []
owner= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[2]")
for i in owner:
    o.append(i.text)
f = []
fuel= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/ul/li[3]")
for i in fuel:
    f.append(i.text)
e = []
emi= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[1]/strong")
for i in emi:
    e.append(i.text.replace('₹',''))
p = []
price= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[2]/div[2]/span")
for i in price:
    p.append(i.text.replace('₹',''))
d = []
downpayment= driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div/div[3]/div/div/div/a/div[2]/div[3]/span")
for i in downpayment:
    d.append(i.text)

time.sleep(2)        
#creating dataframe
df10=pd.DataFrame({'Brand':b,'Model':m,'Year Of Purchase':y,'Transmission':t,'Kilometers Drive Till Now':k,'Owner':o,'Feul':f,'EMI':e,'Price Of Car':p,'Downpayment':d})

# %%
Location = 'Agra'

# %%
df10['Location'] = Location

# %%
df10
# Out:
#                        Brand                     Model  \
# 0          2017 Maruti Swift            VXI OPT Manual
# 1          2017 Nissan Sunny               XE D Manual
# 2    2017 Maruti Swift Dzire      ZXI 1.2 BS IV Manual
# 3        2016 Renault Duster  RXL AMT 110 PS Automatic
# 4            2018 Honda WR-V   1.2 i-VTEC VX MT Manual
# ..                       ...                       ...
# 180         2019 Maruti Alto                LXI Manual
# 181     2017 Maruti Alto K10                VXI Manual
# 182     2017 Maruti Alto K10                VXI Manual
# 183     2017 Maruti Alto K10                VXI Manual
# 184        2020 Toyota YARIS           G CVT Automatic
#
#             Year Of Purchase Transmission Kilometers Drive Till Now  \
# 0          2017 Maruti Swift       Manual               1,30,814 km
# 1          2017 Nissan Sunny       Manual               1,21,004 km
# 2    2017 Maruti Swift Dzire       Manual                 65,284 km
# ...

# %%
CarPricePrediction=pd.concat([df,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10])
CarPricePrediction
# Out:
#                        Brand                  Model         Year Of Purchase  \
# 0       2014 Maruti Alto K10             VXI Manual     2014 Maruti Alto K10
# 1     2015 Hyundai Grand i10  MAGNA 1.1 CRDI Manual   2015 Hyundai Grand i10
# 2    2014 Maruti Swift Dzire       VDI BS IV Manual  2014 Maruti Swift Dzire
# 3          2015 Maruti Swift         VDI ABS Manual        2015 Maruti Swift
# 4       2019 Maruti Alto K10             VXI Manual     2019 Maruti Alto K10
# ..                       ...                    ...                      ...
# 180         2019 Maruti Alto             LXI Manual         2019 Maruti Alto
# 181     2017 Maruti Alto K10             VXI Manual     2017 Maruti Alto K10
# 182     2017 Maruti Alto K10             VXI Manual     2017 Maruti Alto K10
# 183     2017 Maruti Alto K10             VXI Manual     2017 Maruti Alto K10
# 184        2020 Toyota YARIS        G CVT Automatic        2020 Toyota YARIS
#
# ...

# %%
CarPricePrediction['Year Of Purchase']=CarPricePrediction['Year Of Purchase'].str.extract('(\d+)')

# %%
CarPricePrediction['Brand'] = CarPricePrediction['Brand'].str.replace('\d+', '')

# %%
CarPricePrediction
# Out:
#                    Brand                  Model Year Of Purchase Transmission  \
# 0          Maruti Alto K             VXI Manual             2014       Manual
# 1        Hyundai Grand i  MAGNA 1.1 CRDI Manual             2015       Manual
# 2     Maruti Swift Dzire       VDI BS IV Manual             2014       Manual
# 3           Maruti Swift         VDI ABS Manual             2015       Manual
# 4          Maruti Alto K             VXI Manual             2019       Manual
# ..                   ...                    ...              ...          ...
# 180          Maruti Alto             LXI Manual             2019       Manual
# 181        Maruti Alto K             VXI Manual             2017       Manual
# 182        Maruti Alto K             VXI Manual             2017       Manual
# 183        Maruti Alto K             VXI Manual             2017       Manual
# 184         Toyota YARIS        G CVT Automatic             2020    Automatic
#
# ...

# %%
CarPricePrediction.to_excel("CarPricePredictionData.xlsx",sheet_name='CarPricePrediction')

# %% [markdown]
# # Thanks...!
